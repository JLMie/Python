# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# Conducting Sentiment Analysis¶
# Loading and Exploring Data
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# Notes:
#
# The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
import re

# %%
original_data = pd.read_csv('training.1600000.processed.noemoticon.csv', encoding='latin1')

# %%
#RENAME COLUMNS. 
original_data.columns = ['target','id','date','flag','user','text']
original_data.columns
# I called like this because I did not create a sample first. So I rahter changed this name to avoid replace many times the other name.
# Out:
# Index(['target', 'id', 'date', 'flag', 'user', 'text'], dtype='object')

# %%
original_data.head(10)
# Out:
#    target          id                          date      flag  \
# 0       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 5       0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 6       0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7       0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 8       0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
# 9       0  1467812416  Mon Apr 06 22:20:16 PDT 2009  NO_QUERY
#
#               user                                               text
# 0    scotthamilton  is upset that he can't update his Facebook by ...
# 1         mattycus  @Kenichan I dived many times for the ball. Man...
# 2          ElleCTF    my whole body feels itchy and like its on fire
# 3           Karoli  @nationwideclass no, it's not behaving at all....
# 4         joy_wolf                      @Kwesidei not the whole crew
# 5          mybirch                                        Need a hug
# 6             coZZ  @LOLTrish hey  long time no see! Yes.. Rains a...
# 7  2Hood4Hollywood               @Tatiana_K nope they didn't have it
# 8          mimismo                          @twittera que me muera ?
# 9   erinx3leannexo        spring break in plain city... it's snowing

# %%
data = original_data.sample(n=20000)
data
# Out:
#          target          id                          date      flag  \
# 781935        0  2323528022  Thu Jun 25 00:51:24 PDT 2009  NO_QUERY
# 1344802       4  2039933465  Thu Jun 04 23:10:57 PDT 2009  NO_QUERY
# 1031235       4  1933033820  Tue May 26 22:49:32 PDT 2009  NO_QUERY
# 392428        0  2055146991  Sat Jun 06 08:47:10 PDT 2009  NO_QUERY
# 1502684       4  2071752051  Sun Jun 07 19:52:25 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1544210       4  2181675504  Mon Jun 15 12:08:50 PDT 2009  NO_QUERY
# 432191        0  2064695890  Sun Jun 07 06:56:54 PDT 2009  NO_QUERY
# 1303071       4  2009019458  Tue Jun 02 15:01:22 PDT 2009  NO_QUERY
# 759619        0  2296303738  Tue Jun 23 09:01:07 PDT 2009  NO_QUERY
# 171573        0  1963280082  Fri May 29 12:29:06 PDT 2009  NO_QUERY
#
#                   user                                               text
# 781935    KaeliTheKool  Just spent 20 minutes watching a commercial on...
# 1344802      LaurHogan  Robert Pattinson Topless Pics!! Oh Lordi ! New...
# 1031235  kristinfinley  @shutupman Awesome  Cemeteries, some fancy ice...
# 392428     miravalonia             blue jeans, over-played for tonight..
# 1502684     snickel727  Waiting for Night at the Museum 2 to start wit...
# ...                ...                                                ...
# 1544210       revjesse                           @tim_shelbourne hahahaa
# 432191         tzejing     needs someone to fetch me home after band tmr
# 1303071    tomatoeMD66  http://twitpic.com/6hpqt - humm, a message in ...
# 759619        tatarina  Its so pretty outside and its ruined cause I d...
# 171573   Caitlynnnnnnn          Mary, Are you not receiving my texts????
#
# [20000 rows x 6 columns]

# %%
data.shape
# Out:
# (20000, 6)

# %%
duplicates = data[data.duplicated()]
duplicate_count = len(duplicates)
print(f"Number of duplicates: {duplicate_count}")
print("Duplicate Rows:")
print(duplicates)
# Out:
# Number of duplicates: 0
# Duplicate Rows:
# Empty DataFrame
# Columns: [target, id, date, flag, user, text]
# Index: []

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data
# Out:
#          target          id                          date      flag  \
# 781935        0  2323528022  Thu Jun 25 00:51:24 PDT 2009  NO_QUERY
# 1344802       4  2039933465  Thu Jun 04 23:10:57 PDT 2009  NO_QUERY
# 1031235       4  1933033820  Tue May 26 22:49:32 PDT 2009  NO_QUERY
# 392428        0  2055146991  Sat Jun 06 08:47:10 PDT 2009  NO_QUERY
# 1502684       4  2071752051  Sun Jun 07 19:52:25 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1544210       4  2181675504  Mon Jun 15 12:08:50 PDT 2009  NO_QUERY
# 432191        0  2064695890  Sun Jun 07 06:56:54 PDT 2009  NO_QUERY
# 1303071       4  2009019458  Tue Jun 02 15:01:22 PDT 2009  NO_QUERY
# 759619        0  2296303738  Tue Jun 23 09:01:07 PDT 2009  NO_QUERY
# 171573        0  1963280082  Fri May 29 12:29:06 PDT 2009  NO_QUERY
#
#                   user                                               text
# 781935    KaeliTheKool  Just spent 20 minutes watching a commercial on...
# 1344802      LaurHogan  Robert Pattinson Topless Pics!! Oh Lordi ! New...
# 1031235  kristinfinley  @shutupman Awesome  Cemeteries, some fancy ice...
# 392428     miravalonia             blue jeans, over-played for tonight..
# 1502684     snickel727  Waiting for Night at the Museum 2 to start wit...
# ...                ...                                                ...
# 1544210       revjesse                           @tim_shelbourne hahahaa
# 432191         tzejing     needs someone to fetch me home after band tmr
# 1303071    tomatoeMD66  http://twitpic.com/6hpqt - humm, a message in ...
# 759619        tatarina  Its so pretty outside and its ruined cause I d...
# 171573   Caitlynnnnnnn          Mary, Are you not receiving my texts????
#
# [20000 rows x 6 columns]

# %%
#Cheking if there are empty values.
blank_values = data[data == ' '].count()
blank_values
# Out:
# target    0
# id        0
# date      0
# flag      0
# user      0
# text      0
# dtype: int64

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# %%time
def clean_up(s):
    s = re.sub(r"http\S+|www\S+|https\S+", "", s)
    s = re.sub(r"[^a-zA-Z]", " ", s)
    s = s.lower()
    return s

def my_tokenize(s):
    return word_tokenize(s)

def lemmatize(l):
    lemmatizer = WordNetLemmatizer()
    return [lemmatizer.lemmatize(word) for word in l]

def remove_stopwords(l):
    stop_words = set(stopwords.words('english'))
    return [word for word in l if word not in stop_words]
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
data['text_processed'] = data['text'].apply(clean_up)
data['text_processed'] = data['text_processed'].apply(my_tokenize)
data['text_processed'] = data['text_processed'].apply(lemmatize)
data['text_processed'] = data['text_processed'].apply(remove_stopwords)
# Out:
# CPU times: total: 8.8 s
# Wall time: 18.1 s

# %%
data
# Out:
#          target          id                          date      flag  \
# 781935        0  2323528022  Thu Jun 25 00:51:24 PDT 2009  NO_QUERY
# 1344802       4  2039933465  Thu Jun 04 23:10:57 PDT 2009  NO_QUERY
# 1031235       4  1933033820  Tue May 26 22:49:32 PDT 2009  NO_QUERY
# 392428        0  2055146991  Sat Jun 06 08:47:10 PDT 2009  NO_QUERY
# 1502684       4  2071752051  Sun Jun 07 19:52:25 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1544210       4  2181675504  Mon Jun 15 12:08:50 PDT 2009  NO_QUERY
# 432191        0  2064695890  Sun Jun 07 06:56:54 PDT 2009  NO_QUERY
# 1303071       4  2009019458  Tue Jun 02 15:01:22 PDT 2009  NO_QUERY
# 759619        0  2296303738  Tue Jun 23 09:01:07 PDT 2009  NO_QUERY
# 171573        0  1963280082  Fri May 29 12:29:06 PDT 2009  NO_QUERY
#
#                   user                                               text  \
# 781935    KaeliTheKool  Just spent 20 minutes watching a commercial on...
# 1344802      LaurHogan  Robert Pattinson Topless Pics!! Oh Lordi ! New...
# 1031235  kristinfinley  @shutupman Awesome  Cemeteries, some fancy ice...
# 392428     miravalonia             blue jeans, over-played for tonight..
# 1502684     snickel727  Waiting for Night at the Museum 2 to start wit...
# ...                ...                                                ...
# 1544210       revjesse                           @tim_shelbourne hahahaa
# 432191         tzejing     needs someone to fetch me home after band tmr
# 1303071    tomatoeMD66  http://twitpic.com/6hpqt - humm, a message in ...
# 759619        tatarina  Its so pretty outside and its ruined cause I d...
# 171573   Caitlynnnnnnn          Mary, Are you not receiving my texts????
#
#                                             text_processed
# 781935   [spent, minute, watching, commercial, slim, n,...
# 1344802  [robert, pattinson, topless, pic, oh, lordi, n...
# 1031235  [shutupman, awesome, cemetery, fancy, ice, cre...
# 392428                       [blue, jean, played, tonight]
# 1502684      [waiting, night, museum, start, uncbear, yay]
# ...                                                    ...
# 1544210                         [tim, shelbourne, hahahaa]
# 432191             [need, someone, fetch, home, band, tmr]
# 1303071  [humm, message, bottle, fan, mail, flounder, b...
# 759619        [pretty, outside, ruined, cause, feel, well]
# 171573                             [mary, receiving, text]
#
# [20000 rows x 7 columns]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
from nltk import FreqDist
words_bag = [word for sublist in data['text_processed'] for word in sublist]

freq_dist = FreqDist(words_bag)

common_words = freq_dist.most_common(5000)
common_words
# Out:
# [('day', 1434),
#  ('wa', 1269),
#  ('good', 1189),
#  ('go', 1071),
#  ('get', 1063),
#  ('like', 984),
#  ('quot', 982),
#  ('got', 935),
#  ('today', 883),
#  ('u', 850),
#  ('love', 847),
#  ('going', 837),
#  ('time', 837),
#  ('work', 832),
#  ('back', 743),
#  ('know', 696),
#  ('lol', 695),
#  ('one', 675),
#  ('really', 642),
#  ('im', 634),
#  ('night', 630),
#  ('want', 623),
#  ('amp', 618),
#  ('still', 572),
#  ('see', 566),
#  ('na', 545),
#  ('home', 540),
#  ('new', 529),
#  ('well', 513),
#  ('think', 510),
#  ('miss', 507),
#  ('thanks', 503),
#  ('need', 499),
#  ('last', 493),
#  ('ha', 484),
#  ('oh', 451),
#  ('morning', 450),
#  ('hope', 445),
#  ('feel', 434),
#  ('much', 430),
#  ('make', 424),
#  ('tomorrow', 424),
#  ('twitter', 410),
#  ('great', 405),
#  ('haha', 392),
#  ('wish', 381),
#  ('friend', 379),
#  ('come', 360),
#  ('happy', 357),
#  ('fun', 356),
#  ('sad', 355),
#  ('thing', 344),
#  ('right', 344),
#  ('would', 338),
#  ('week', 327),
#  ('bad', 326),
#  ('sorry', 320),
#  ('sleep', 318),
#  ('getting', 318),
#  ('tonight', 316),
#  ('gon', 313),
#  ('though', 308),
#  ('watching', 301),
#  ('bed', 301),
#  ('look', 299),
#  ('way', 295),
#  ('nice', 295),
#  ('better', 289),
#  ('guy', 289),
#  ('say', 285),
#  ('yeah', 283),
#  ('hate', 276),
#  ('could', 269),
#  ('school', 265),
#  ('show', 263),
#  ('wait', 258),
#  ('girl', 252),
#  ('lt', 249),
#  ('people', 247),
#  ('hey', 243),
#  ('hour', 242),
#  ('tired', 241),
#  ('yes', 241),
#  ('weekend', 238),
#  ('x', 236),
#  ('movie', 236),
#  ('take', 235),
#  ('dont', 234),
#  ('never', 230),
#  ('tweet', 229),
#  ('first', 227),
#  ('even', 226),
#  ('next', 226),
#  ('long', 224),
#  ('awesome', 222),
#  ('life', 221),
#  ('watch', 219),
#  ('soon', 218),
#  ('working', 218),
#  ('let', 215),
#  ('done', 215),
#  ('thank', 215),
#  ('everyone', 213),
#  ('wan', 213),
#  ('best', 212),
#  ('please', 208),
#  ('sick', 207),
#  ('ur', 206),
#  ('suck', 204),
#  ('ready', 201),
#  ('find', 200),
#  ('cant', 194),
#  ('feeling', 194),
#  ('already', 193),
#  ('another', 193),
#  ('year', 191),
#  ('cool', 190),
#  ('b', 189),
#  ('looking', 188),
#  ('little', 187),
#  ('summer', 186),
#  ('yay', 183),
#  ('sure', 182),
#  ('ok', 181),
#  ('help', 181),
#  ('lot', 179),
#  ('phone', 174),
#  ('n', 173),
#  ('something', 173),
#  ('ever', 173),
#  ('keep', 170),
#  ('hurt', 169),
#  ('song', 166),
#  ('thought', 166),
#  ('trying', 164),
#  ('went', 164),
#  ('always', 163),
#  ('damn', 162),
#  ('yet', 161),
#  ('house', 159),
#  ('someone', 156),
#  ('hot', 156),
#  ('made', 156),
#  ('pretty', 155),
#  ('amazing', 155),
#  ('guess', 153),
#  ('missed', 151),
#  ('rain', 150),
#  ('lost', 149),
#  ('sound', 148),
#  ('big', 148),
#  ('baby', 147),
#  ('ta', 147),
#  ('finally', 147),
#  ('w', 147),
#  ('wow', 147),
#  ('start', 146),
#  ('call', 145),
#  ('old', 144),
#  ('follow', 144),
#  ('early', 143),
#  ('ya', 143),
#  ('said', 143),
#  ('away', 141),
#  ('stuff', 140),
#  ('glad', 140),
#  ('game', 139),
#  ('maybe', 139),
#  ('p', 139),
#  ('ugh', 139),
#  ('actually', 139),
#  ('try', 138),
#  ('pic', 137),
#  ('tell', 137),
#  ('omg', 137),
#  ('man', 136),
#  ('god', 136),
#  ('nothing', 136),
#  ('yesterday', 135),
#  ('bit', 135),
#  ('left', 135),
#  ('two', 133),
#  ('car', 132),
#  ('mom', 132),
#  ('also', 132),
#  ('weather', 132),
#  ('sun', 131),
#  ('th', 131),
#  ('waiting', 130),
#  ('saw', 130),
#  ('around', 128),
#  ('birthday', 126),
#  ('sunday', 126),
#  ('mean', 125),
#  ('live', 125),
#  ('give', 125),
#  ('bored', 125),
#  ('excited', 124),
#  ('party', 124),
#  ('later', 124),
#  ('luck', 124),
#  ('since', 123),
#  ('stop', 122),
#  ('coming', 122),
#  ('friday', 122),
#  ('might', 121),
#  ('kid', 121),
#  ('aww', 120),
#  ('doe', 120),
#  ('play', 120),
#  ('many', 119),
#  ('music', 118),
#  ('hear', 118),
#  ('r', 115),
#  ('thats', 114),
#  ('world', 114),
#  ('late', 114),
#  ('talk', 113),
#  ('job', 112),
#  ('hard', 112),
#  ('exam', 112),
#  ('monday', 111),
#  ('cold', 111),
#  ('video', 110),
#  ('head', 110),
#  ('use', 110),
#  ('funny', 109),
#  ('must', 109),
#  ('boy', 109),
#  ('mother', 109),
#  ('follower', 108),
#  ('check', 108),
#  ('making', 106),
#  ('listening', 105),
#  ('put', 104),
#  ('woke', 104),
#  ('found', 104),
#  ('forward', 103),
#  ('cute', 103),
#  ('finished', 103),
#  ('hi', 102),
#  ('hair', 102),
#  ('anyone', 102),
#  ('gone', 102),
#  ('thinking', 102),
#  ('cause', 101),
#  ('far', 101),
#  ('beautiful', 101),
#  ('least', 99),
#  ('read', 99),
#  ('leave', 99),
#  ('dinner', 99),
#  ('enjoy', 99),
#  ('food', 99),
#  ('word', 98),
#  ('anything', 98),
#  ('iphone', 98),
#  ('real', 98),
#  ('may', 98),
#  ('picture', 98),
#  ('missing', 97),
#  ('family', 97),
#  ('shit', 97),
#  ('month', 96),
#  ('fan', 96),
#  ('dream', 96),
#  ('eat', 96),
#  ('class', 95),
#  ('sooo', 95),
#  ('playing', 95),
#  ('every', 94),
#  ('update', 94),
#  ('gt', 94),
#  ('c', 93),
#  ('end', 93),
#  ('place', 93),
#  ('took', 92),
#  ('almost', 92),
#  ('brother', 91),
#  ('hello', 91),
#  ('cry', 91),
#  ('sweet', 90),
#  ('book', 90),
#  ('tv', 90),
#  ('lunch', 90),
#  ('saturday', 90),
#  ('stay', 89),
#  ('welcome', 89),
#  ('poor', 88),
#  ('buy', 87),
#  ('win', 87),
#  ('tho', 87),
#  ('face', 86),
#  ('eating', 86),
#  ('mine', 86),
#  ('everything', 86),
#  ('without', 86),
#  ('wanted', 85),
#  ('part', 85),
#  ('totally', 84),
#  ('name', 84),
#  ('soo', 84),
#  ('eye', 83),
#  ('used', 83),
#  ('dog', 82),
#  ('room', 82),
#  ('xx', 82),
#  ('till', 82),
#  ('busy', 82),
#  ('minute', 81),
#  ('ill', 81),
#  ('free', 81),
#  ('seen', 80),
#  ('hell', 80),
#  ('okay', 80),
#  ('st', 79),
#  ('final', 79),
#  ('watched', 79),
#  ('outside', 79),
#  ('didnt', 79),
#  ('trip', 79),
#  ('lovely', 79),
#  ('office', 78),
#  ('enough', 78),
#  ('kinda', 78),
#  ('post', 78),
#  ('headache', 78),
#  ('believe', 77),
#  ('stupid', 77),
#  ('money', 77),
#  ('crazy', 77),
#  ('taking', 76),
#  ('remember', 76),
#  ('heard', 75),
#  ('reply', 75),
#  ('anymore', 75),
#  ('wrong', 75),
#  ('idea', 75),
#  ('following', 75),
#  ('plan', 75),
#  ('beach', 74),
#  ('goodnight', 74),
#  ('e', 74),
#  ('fuck', 73),
#  ('hahaha', 73),
#  ('mileycyrus', 73),
#  ('hopefully', 73),
#  ('season', 73),
#  ('came', 72),
#  ('sitting', 72),
#  ('coffee', 72),
#  ('whole', 71),
#  ('hehe', 71),
#  ('stuck', 70),
#  ('full', 70),
#  ('break', 70),
#  ('text', 69),
#  ('able', 69),
#  ('dad', 68),
#  ('half', 68),
#  ('pm', 68),
#  ('probably', 67),
#  ('nite', 67),
#  ('shower', 67),
#  ('shopping', 67),
#  ('run', 66),
#  ('award', 66),
#  ('started', 66),
#  ('rest', 66),
#  ('k', 66),
#  ('g', 66),
#  ('blog', 66),
#  ('else', 66),
#  ('computer', 65),
#  ('quite', 65),
#  ('forgot', 65),
#  ('dude', 65),
#  ('hand', 65),
#  ('ah', 65),
#  ('tried', 65),
#  ('train', 64),
#  ('hug', 64),
#  ('alone', 64),
#  ('btw', 63),
#  ('wont', 63),
#  ('cat', 63),
#  ('enjoying', 63),
#  ('reading', 63),
#  ('boring', 63),
#  ('lucky', 63),
#  ('rock', 62),
#  ('open', 62),
#  ('link', 62),
#  ('wake', 62),
#  ('la', 62),
#  ('page', 61),
#  ('photo', 61),
#  ('either', 61),
#  ('sigh', 61),
#  ('yea', 61),
#  ('boo', 60),
#  ('turn', 60),
#  ('meet', 60),
#  ('raining', 60),
#  ('crap', 60),
#  ('kind', 59),
#  ('course', 59),
#  ('heart', 59),
#  ('site', 59),
#  ('hit', 59),
#  ('leaving', 59),
#  ('facebook', 59),
#  ('breakfast', 59),
#  ('send', 58),
#  ('fine', 58),
#  ('l', 58),
#  ('ago', 58),
#  ('true', 58),
#  ('problem', 58),
#  ('june', 57),
#  ('seeing', 57),
#  ('hungry', 57),
#  ('mr', 57),
#  ('afternoon', 57),
#  ('super', 57),
#  ('cuz', 57),
#  ('mum', 56),
#  ('favorite', 56),
#  ('listen', 56),
#  ('internet', 56),
#  ('high', 56),
#  ('add', 56),
#  ('asleep', 56),
#  ('concert', 56),
#  ('happened', 56),
#  ('air', 56),
#  ('evening', 56),
#  ('story', 55),
#  ('move', 55),
#  ('hoping', 55),
#  ('drink', 55),
#  ('nd', 55),
#  ('news', 55),
#  ('using', 55),
#  ('starting', 55),
#  ('loved', 55),
#  ('com', 55),
#  ('line', 54),
#  ('test', 54),
#  ('lmao', 54),
#  ('homework', 54),
#  ('sister', 54),
#  ('city', 54),
#  ('seems', 54),
#  ('died', 53),
#  ('smile', 53),
#  ('awake', 53),
#  ('broke', 53),
#  ('ticket', 53),
#  ('second', 53),
#  ('care', 53),
#  ('town', 52),
#  ('h', 52),
#  ('change', 52),
#  ('sleeping', 52),
#  ('study', 52),
#  ('tommcfly', 51),
#  ('mind', 51),
#  ('told', 51),
#  ('til', 51),
#  ('park', 51),
#  ('ride', 51),
#  ('email', 51),
#  ('seriously', 50),
#  ('v', 50),
#  ('catch', 50),
#  ('xd', 50),
#  ('heading', 50),
#  ('studying', 50),
#  ('gym', 50),
#  ('dear', 50),
#  ('set', 50),
#  ('meeting', 50),
#  ('write', 50),
#  ('jonas', 50),
#  ('agree', 50),
#  ('pain', 50),
#  ('sore', 49),
#  ('close', 49),
#  ('voice', 49),
#  ('red', 49),
#  ('sometimes', 49),
#  ('walk', 49),
#  ('couple', 49),
#  ('black', 49),
#  ('online', 49),
#  ('sunny', 48),
#  ('pay', 48),
#  ('pool', 48),
#  ('store', 48),
#  ('dead', 48),
#  ('ice', 47),
#  ('talking', 47),
#  ('laptop', 47),
#  ('happen', 47),
#  ('drive', 47),
#  ('bring', 47),
#  ('min', 47),
#  ('hang', 47),
#  ('bought', 47),
#  ('account', 47),
#  ('ive', 47),
#  ('jealous', 47),
#  ('lady', 47),
#  ('foot', 47),
#  ('ipod', 46),
#  ('answer', 46),
#  ('vote', 46),
#  ('list', 46),
#  ('lil', 46),
#  ('wishing', 46),
#  ('flight', 46),
#  ('slow', 46),
#  ('bus', 46),
#  ('tweeting', 45),
#  ('wonderful', 45),
#  ('fail', 45),
#  ('chocolate', 45),
#  ('tea', 45),
#  ('bday', 45),
#  ('cleaning', 45),
#  ('fall', 45),
#  ('ate', 45),
#  ('number', 45),
#  ('worth', 45),
#  ('aw', 44),
#  ('ask', 44),
#  ('together', 44),
#  ('called', 44),
#  ('church', 44),
#  ('inside', 44),
#  ('cut', 44),
#  ('date', 44),
#  ('youtube', 44),
#  ('fb', 44),
#  ('goin', 44),
#  ('forget', 44),
#  ('note', 43),
#  ('visit', 43),
#  ('three', 43),
#  ('window', 43),
#  ('math', 43),
#  ('tour', 43),
#  ('cheer', 43),
#  ('anyway', 43),
#  ('short', 43),
#  ('scared', 43),
#  ('holiday', 43),
#  ('cream', 42),
#  ('reason', 42),
#  ('apparently', 42),
#  ('finish', 42),
#  ('bout', 42),
#  ('soooo', 42),
#  ('episode', 42),
#  ('awww', 42),
#  ('weird', 42),
#  ('age', 42),
#  ('ahhh', 42),
#  ('ddlovato', 42),
#  ('learn', 41),
#  ('album', 41),
#  ('writing', 41),
#  ('le', 41),
#  ('bye', 41),
#  ('seem', 41),
#  ('shame', 41),
#  ('clean', 41),
#  ('side', 41),
#  ('shoe', 41),
#  ('mac', 40),
#  ('rather', 40),
#  ('worry', 40),
#  ('july', 40),
#  ('point', 40),
#  ('ppl', 40),
#  ('chance', 40),
#  ('nap', 40),
#  ('mad', 40),
#  ('team', 40),
#  ('congrats', 40),
#  ('sunshine', 40),
#  ('person', 40),
#  ('sent', 39),
#  ('top', 39),
#  ('wear', 39),
#  ('radio', 39),
#  ('definitely', 39),
#  ('flu', 39),
#  ('instead', 39),
#  ('fast', 39),
#  ('tuesday', 39),
#  ('blue', 38),
#  ('f', 38),
#  ('star', 38),
#  ('london', 38),
#  ('english', 38),
#  ('shot', 38),
#  ('understand', 38),
#  ('water', 38),
#  ('xxx', 38),
#  ('j', 38),
#  ('dance', 38),
#  ('paper', 37),
#  ('si', 37),
#  ('band', 37),
#  ('slept', 37),
#  ('moving', 37),
#  ('david', 37),
#  ('interesting', 37),
#  ('wonder', 37),
#  ('easy', 37),
#  ('camp', 37),
#  ('sleepy', 37),
#  ('clothes', 36),
#  ('loving', 36),
#  ('hangover', 36),
#  ('throat', 36),
#  ('power', 36),
#  ('pick', 36),
#  ('nick', 36),
#  ('knew', 36),
#  ('worst', 36),
#  ('service', 36),
#  ('ahh', 36),
#  ('beer', 36),
#  ('unfortunately', 36),
#  ('yummy', 36),
#  ('broken', 36),
#  ('yep', 36),
#  ('running', 36),
#  ('doesnt', 36),
#  ('parent', 36),
#  ('moon', 35),
#  ('woman', 35),
#  ('fell', 35),
#  ('supposed', 35),
#  ('followfriday', 35),
#  ('miley', 35),
#  ('join', 35),
#  ('fix', 35),
#  ('bitch', 35),
#  ('hubby', 35),
#  ('perfect', 35),
#  ('wtf', 35),
#  ('nope', 34),
#  ('angel', 34),
#  ('thx', 34),
#  ('xoxo', 34),
#  ('random', 34),
#  ('pas', 34),
#  ('project', 34),
#  ('horrible', 34),
#  ('boyfriend', 34),
#  ('dm', 34),
#  ('hr', 34),
#  ('bet', 34),
#  ('em', 34),
#  ('hmmm', 33),
#  ('doctor', 33),
#  ('mtv', 33),
#  ('special', 33),
#  ('da', 33),
#  ('shirt', 33),
#  ('felt', 33),
#  ('wine', 33),
#  ('mood', 33),
#  ('storm', 33),
#  ('question', 33),
#  ('ring', 33),
#  ('lonely', 33),
#  ('spend', 33),
#  ('yr', 33),
#  ('whatever', 33),
#  ('hmm', 32),
#  ('cake', 32),
#  ('havent', 32),
#  ('watchin', 32),
#  ('driving', 32),
#  ('gave', 32),
#  ('plus', 32),
#  ('via', 32),
#  ('country', 32),
#  ('wedding', 32),
#  ('forever', 32),
#  ('order', 32),
#  ('chat', 32),
#  ('light', 32),
#  ('bike', 32),
#  ('everybody', 32),
#  ('joe', 31),
#  ('message', 31),
#  ('drinking', 31),
#  ('load', 31),
#  ('along', 31),
#  ('fml', 31),
#  ('vacation', 31),
#  ('fair', 31),
#  ('apple', 31),
#  ('camera', 31),
#  ('ouch', 31),
#  ('sat', 31),
#  ('garden', 31),
#  ('bbq', 31),
#  ('past', 31),
#  ('babe', 31),
#  ('lakers', 31),
#  ('green', 31),
#  ('result', 31),
#  ('revision', 30),
#  ('asked', 30),
#  ('mail', 30),
#  ('gorgeous', 30),
#  ('wondering', 30),
#  ('jus', 30),
#  ('worried', 30),
#  ('puppy', 30),
#  ('honey', 30),
#  ('exactly', 30),
#  ('bloody', 30),
#  ('single', 30),
#  ('leg', 30),
#  ('moment', 30),
#  ('shoot', 30),
#  ('thursday', 30),
#  ('wit', 30),
#  ('disappointed', 30),
#  ('saying', 30),
#  ('fly', 30),
#  ('dress', 30),
#  ('demi', 30),
#  ('bag', 30),
#  ('alright', 30),
#  ('blah', 30),
#  ('goodbye', 30),
#  ('spent', 29),
#  ('played', 29),
#  ('front', 29),
#  ('fact', 29),
#  ('walking', 29),
#  ('sale', 29),
#  ('matter', 29),
#  ('cover', 29),
#  ('beat', 29),
#  ('app', 29),
#  ('body', 29),
#  ('ooh', 29),
#  ('box', 29),
#  ('guitar', 29),
#  ('absolutely', 29),
#  ('mommy', 29),
#  ('hanging', 29),
#  ('relaxing', 29),
#  ('passed', 29),
#  ('tummy', 29),
#  ('uk', 29),
#  ('eh', 29),
#  ('due', 29),
#  ('upset', 29),
#  ('kill', 29),
#  ('living', 29),
#  ('french', 29),
#  ('killing', 29),
#  ('record', 29),
#  ('longer', 29),
#  ('whats', 29),
#  ('near', 29),
#  ('traffic', 29),
#  ('co', 29),
#  ('touch', 28),
#  ('figure', 28),
#  ('arm', 28),
#  ('turned', 28),
#  ('group', 28),
#  ('share', 28),
#  ('different', 28),
#  ('posted', 28),
#  ('hill', 28),
#  ('fit', 28),
#  ('sign', 28),
#  ('warm', 28),
#  ('wet', 28),
#  ('bummed', 28),
#  ('worked', 28),
#  ('safe', 28),
#  ('website', 28),
#  ('comment', 28),
#  ('lazy', 28),
#  ('smell', 28),
#  ('fucking', 28),
#  ('trailer', 28),
#  ('card', 28),
#  ('hospital', 28),
#  ('xo', 28),
#  ('john', 28),
#  ('ohh', 28),
#  ('stand', 27),
#  ('case', 27),
#  ('jonasbrothers', 27),
#  ('father', 27),
#  ('singing', 27),
#  ('freaking', 27),
#  ('art', 27),
#  ('cup', 27),
#  ('club', 27),
#  ('pizza', 27),
#  ('rainy', 27),
#  ('version', 27),
#  ('packing', 27),
#  ('ache', 27),
#  ('die', 27),
#  ('airport', 27),
#  ('magic', 27),
#  ('yup', 27),
#  ('deal', 27),
#  ('officially', 27),
#  ('white', 27),
#  ('looked', 27),
#  ('drunk', 27),
#  ('door', 27),
#  ('rip', 27),
#  ('earlier', 27),
#  ('shop', 26),
#  ('ball', 26),
#  ('hold', 26),
#  ('chris', 26),
#  ('ear', 26),
#  ('dark', 26),
#  ('except', 26),
#  ('company', 26),
#  ('silly', 26),
#  ('stomach', 26),
#  ('round', 26),
#  ('failed', 26),
#  ('proud', 26),
#  ('joy', 26),
#  ('chicken', 26),
#  ('dvd', 26),
#  ('business', 26),
#  ('hun', 26),
#  ('dying', 26),
#  ('glass', 26),
#  ('tear', 26),
#  ('web', 26),
#  ('aint', 26),
#  ('promise', 26),
#  ('huge', 26),
#  ('profile', 25),
#  ('self', 25),
#  ('graduation', 25),
#  ('woo', 25),
#  ('happens', 25),
#  ('tom', 25),
#  ('asking', 25),
#  ('although', 25),
#  ('son', 25),
#  ('lame', 25),
#  ('awful', 25),
#  ('sum', 25),
#  ('wednesday', 25),
#  ('track', 25),
#  ('event', 25),
#  ('bro', 25),
#  ('type', 25),
#  ('behind', 25),
#  ('trouble', 25),
#  ('twilight', 25),
#  ('idk', 25),
#  ('spending', 25),
#  ('sims', 25),
#  ('pc', 25),
#  ('american', 25),
#  ('rd', 25),
#  ('decided', 25),
#  ('studio', 24),
#  ('straight', 24),
#  ('google', 24),
#  ('yo', 24),
#  ('vega', 24),
#  ('gettin', 24),
#  ('nobody', 24),
#  ('mile', 24),
#  ('vip', 24),
#  ('enjoyed', 24),
#  ('sadly', 24),
#  ('wat', 24),
#  ('teacher', 24),
#  ('taylor', 24),
#  ('sarah', 24),
#  ('match', 24),
#  ('met', 24),
#  ('needed', 24),
#  ('mcfly', 24),
#  ('coz', 24),
#  ('ended', 24),
#  ('de', 24),
#  ('support', 24),
#  ('id', 24),
#  ('myspace', 24),
#  ('cook', 24),
#  ('cd', 24),
#  ('usually', 24),
#  ('screen', 24),
#  ('alex', 24),
#  ('film', 24),
#  ('interview', 24),
#  ('france', 24),
#  ('currently', 24),
#  ('normal', 24),
#  ('laugh', 24),
#  ('cheese', 24),
#  ('sexy', 23),
#  ('nose', 23),
#  ('report', 23),
#  ('worse', 23),
#  ('major', 23),
#  ('south', 23),
#  ('tan', 23),
#  ('sort', 23),
#  ('meant', 23),
#  ('wife', 23),
#  ('couch', 23),
#  ('luv', 23),
#  ('gig', 23),
#  ('mmm', 23),
#  ('delicious', 23),
#  ('ton', 23),
#  ('sold', 23),
#  ('ahead', 23),
#  ('tree', 23),
#  ('count', 23),
#  ('low', 23),
#  ('upload', 23),
#  ('plane', 23),
#  ('college', 23),
#  ('bb', 23),
#  ('annoying', 23),
#  ('positive', 23),
#  ('especially', 23),
#  ('finger', 22),
#  ('talent', 22),
#  ('crash', 22),
#  ('def', 22),
#  ('ny', 22),
#  ('return', 22),
#  ('tip', 22),
#  ('arrived', 22),
#  ('hahah', 22),
#  ('nyc', 22),
#  ('ran', 22),
#  ('isnt', 22),
#  ('daughter', 22),
#  ('scary', 22),
#  ('healthy', 22),
#  ('depressed', 22),
#  ('teeth', 22),
#  ('knee', 22),
#  ('chillin', 22),
#  ('street', 22),
#  ('hotel', 22),
#  ('completely', 22),
#  ('indeed', 22),
#  ('cousin', 22),
#  ('waking', 22),
#  ('exciting', 22),
#  ('mi', 22),
#  ('alot', 22),
#  ('pink', 22),
#  ('changed', 22),
#  ('degree', 22),
#  ('finding', 22),
#  ('soccer', 22),
#  ('finishing', 22),
#  ('yall', 22),
#  ('bank', 22),
#  ('kiss', 22),
#  ('click', 22),
#  ('shut', 22),
#  ('liked', 22),
#  ('butt', 22),
#  ('state', 22),
#  ('terrible', 22),
#  ('fat', 21),
#  ('killed', 21),
#  ('ff', 21),
#  ('drop', 21),
#  ('shift', 21),
#  ('download', 21),
#  ('festival', 21),
#  ('contact', 21),
#  ...]

# %%
len(common_words)
# Out:
# 5000

# %%
data['target'].value_counts()
# Out:
# 4    10103
# 0     9897
# Name: target, dtype: int64

# %%
data.columns
# Out:
# Index(['target', 'id', 'date', 'flag', 'user', 'text', 'text_processed'], dtype='object')

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %%
#Following the video. 
#documents = [(list(movie_reviews.words(fileid)), category)
       #for category in movie_reviews.categories()
       #for fileid in movie_reviews.fileids(category)]
        
# random.shuffle(documents)

# %%
def find_features(document):
    words = set(document)
    features = {}
    for w in common_words:
        features[w] = (w in words)
    
    return features

# %% [markdown]
#  The code finds the common words in a document.
#  It then creates an empty dictionary called features and stores each word in it as a key-value pair.
#  The code finds all of the words that are not already in the dictionary, which is set to be common_words.
#  Then, for each word found, it checks if that word is also present in the list of keys stored inside features.
#  If so, then its value will be 1 (true) and if not, its value will be 0 (false).
#  The code will return a dictionary of features that are in the document.

# %%
feature_set = [(find_features(data), target) for (data, target) in list(zip(data['text_processed'], data['target']))]
print(len(feature_set))
# Out:
# 20000

# %% [markdown]
#  The code starts by creating a list of all the features in the data and their corresponding target.
#  The code then iterates over this list, using zip to create a new list with each element being either an item from the original list or None if it was not found.
#  This is done for every feature/target combination in the data set.
#  The code compiles a list of all the features and their corresponding target.

# %%
feature_set[:8]
# Out:
# [({('day', 1434): False,
#    ('wa', 1269): False,
#    ('good', 1189): False,
#    ('go', 1071): False,
#    ('get', 1063): False,
#    ('like', 984): False,
#    ('quot', 982): False,
#    ('got', 935): False,
#    ('today', 883): False,
#    ('u', 850): False,
#    ('love', 847): False,
#    ('going', 837): False,
#    ('time', 837): False,
#    ('work', 832): False,
#    ('back', 743): False,
#    ('know', 696): False,
#    ('lol', 695): False,
#    ('one', 675): False,
#    ('really', 642): False,
#    ('im', 634): False,
#    ('night', 630): False,
#    ('want', 623): False,
#    ('amp', 618): False,
#    ('still', 572): False,
#    ('see', 566): False,
#    ('na', 545): False,
#    ('home', 540): False,
#    ('new', 529): False,
#    ('well', 513): False,
#    ('think', 510): False,
#    ('miss', 507): False,
#    ('thanks', 503): False,
#    ('need', 499): False,
#    ('last', 493): False,
#    ('ha', 484): False,
#    ('oh', 451): False,
#    ('morning', 450): False,
#    ('hope', 445): False,
#    ('feel', 434): False,
#    ('much', 430): False,
#    ('make', 424): False,
#    ('tomorrow', 424): False,
#    ('twitter', 410): False,
#    ('great', 405): False,
#    ('haha', 392): False,
#    ('wish', 381): False,
#    ('friend', 379): False,
#    ('come', 360): False,
#    ('happy', 357): False,
#    ('fun', 356): False,
#    ('sad', 355): False,
#    ('thing', 344): False,
#    ('right', 344): False,
#    ('would', 338): False,
#    ('week', 327): False,
#    ('bad', 326): False,
#    ('sorry', 320): False,
#    ('sleep', 318): False,
#    ('getting', 318): False,
#    ('tonight', 316): False,
#    ('gon', 313): False,
#    ('though', 308): False,
#    ('watching', 301): False,
#    ('bed', 301): False,
#    ('look', 299): False,
#    ('way', 295): False,
#    ('nice', 295): False,
#    ('better', 289): False,
#    ('guy', 289): False,
#    ('say', 285): False,
#    ('yeah', 283): False,
#    ('hate', 276): False,
#    ('could', 269): False,
#    ('school', 265): False,
#    ('show', 263): False,
#    ('wait', 258): False,
#    ('girl', 252): False,
#    ('lt', 249): False,
#    ('people', 247): False,
#    ('hey', 243): False,
#    ('hour', 242): False,
#    ('tired', 241): False,
#    ('yes', 241): False,
#    ('weekend', 238): False,
#    ('x', 236): False,
#    ('movie', 236): False,
#    ('take', 235): False,
#    ('dont', 234): False,
#    ('never', 230): False,
#    ('tweet', 229): False,
#    ('first', 227): False,
#    ('even', 226): False,
#    ('next', 226): False,
#    ('long', 224): False,
#    ('awesome', 222): False,
#    ('life', 221): False,
#    ('watch', 219): False,
#    ('soon', 218): False,
#    ('working', 218): False,
#    ('let', 215): False,
#    ('done', 215): False,
#    ('thank', 215): False,
#    ('everyone', 213): False,
#    ('wan', 213): False,
#    ('best', 212): False,
#    ('please', 208): False,
#    ('sick', 207): False,
#    ('ur', 206): False,
#    ('suck', 204): False,
#    ('ready', 201): False,
#    ('find', 200): False,
#    ('cant', 194): False,
#    ('feeling', 194): False,
#    ('already', 193): False,
#    ('another', 193): False,
#    ('year', 191): False,
#    ('cool', 190): False,
#    ('b', 189): False,
#    ('looking', 188): False,
#    ('little', 187): False,
#    ('summer', 186): False,
#    ('yay', 183): False,
#    ('sure', 182): False,
#    ('ok', 181): False,
#    ('help', 181): False,
#    ('lot', 179): False,
#    ('phone', 174): False,
#    ('n', 173): False,
#    ('something', 173): False,
#    ('ever', 173): False,
#    ('keep', 170): False,
#    ('hurt', 169): False,
#    ('song', 166): False,
#    ('thought', 166): False,
#    ('trying', 164): False,
#    ('went', 164): False,
#    ('always', 163): False,
#    ('damn', 162): False,
#    ('yet', 161): False,
#    ('house', 159): False,
#    ('someone', 156): False,
#    ('hot', 156): False,
#    ('made', 156): False,
#    ('pretty', 155): False,
#    ('amazing', 155): False,
#    ('guess', 153): False,
#    ('missed', 151): False,
#    ('rain', 150): False,
#    ('lost', 149): False,
#    ('sound', 148): False,
#    ('big', 148): False,
#    ('baby', 147): False,
#    ('ta', 147): False,
#    ('finally', 147): False,
#    ('w', 147): False,
#    ('wow', 147): False,
#    ('start', 146): False,
#    ('call', 145): False,
#    ('old', 144): False,
#    ('follow', 144): False,
#    ('early', 143): False,
#    ('ya', 143): False,
#    ('said', 143): False,
#    ('away', 141): False,
#    ('stuff', 140): False,
#    ('glad', 140): False,
#    ('game', 139): False,
#    ('maybe', 139): False,
#    ('p', 139): False,
#    ('ugh', 139): False,
#    ('actually', 139): False,
#    ('try', 138): False,
#    ('pic', 137): False,
#    ('tell', 137): False,
#    ('omg', 137): False,
#    ('man', 136): False,
#    ('god', 136): False,
#    ('nothing', 136): False,
#    ('yesterday', 135): False,
#    ('bit', 135): False,
#    ('left', 135): False,
#    ('two', 133): False,
#    ('car', 132): False,
#    ('mom', 132): False,
#    ('also', 132): False,
#    ('weather', 132): False,
#    ('sun', 131): False,
#    ('th', 131): False,
#    ('waiting', 130): False,
#    ('saw', 130): False,
#    ('around', 128): False,
#    ('birthday', 126): False,
#    ('sunday', 126): False,
#    ('mean', 125): False,
#    ('live', 125): False,
#    ('give', 125): False,
#    ('bored', 125): False,
#    ('excited', 124): False,
#    ('party', 124): False,
#    ('later', 124): False,
#    ('luck', 124): False,
#    ('since', 123): False,
#    ('stop', 122): False,
#    ('coming', 122): False,
#    ('friday', 122): False,
#    ('might', 121): False,
#    ('kid', 121): False,
#    ('aww', 120): False,
#    ('doe', 120): False,
#    ('play', 120): False,
#    ('many', 119): False,
#    ('music', 118): False,
#    ('hear', 118): False,
#    ('r', 115): False,
#    ('thats', 114): False,
#    ('world', 114): False,
#    ('late', 114): False,
#    ('talk', 113): False,
#    ('job', 112): False,
#    ('hard', 112): False,
#    ('exam', 112): False,
#    ('monday', 111): False,
#    ('cold', 111): False,
#    ('video', 110): False,
#    ('head', 110): False,
#    ('use', 110): False,
#    ('funny', 109): False,
#    ('must', 109): False,
#    ('boy', 109): False,
#    ('mother', 109): False,
#    ('follower', 108): False,
#    ('check', 108): False,
#    ('making', 106): False,
#    ('listening', 105): False,
#    ('put', 104): False,
#    ('woke', 104): False,
#    ('found', 104): False,
#    ('forward', 103): False,
#    ('cute', 103): False,
#    ('finished', 103): False,
#    ('hi', 102): False,
#    ('hair', 102): False,
#    ('anyone', 102): False,
#    ('gone', 102): False,
#    ('thinking', 102): False,
#    ('cause', 101): False,
#    ('far', 101): False,
#    ('beautiful', 101): False,
#    ('least', 99): False,
#    ('read', 99): False,
#    ('leave', 99): False,
#    ('dinner', 99): False,
#    ('enjoy', 99): False,
#    ('food', 99): False,
#    ('word', 98): False,
#    ('anything', 98): False,
#    ('iphone', 98): False,
#    ('real', 98): False,
#    ('may', 98): False,
#    ('picture', 98): False,
#    ('missing', 97): False,
#    ('family', 97): False,
#    ('shit', 97): False,
#    ('month', 96): False,
#    ('fan', 96): False,
#    ('dream', 96): False,
#    ('eat', 96): False,
#    ('class', 95): False,
#    ('sooo', 95): False,
#    ('playing', 95): False,
#    ('every', 94): False,
#    ('update', 94): False,
#    ('gt', 94): False,
#    ('c', 93): False,
#    ('end', 93): False,
#    ('place', 93): False,
#    ('took', 92): False,
#    ('almost', 92): False,
#    ('brother', 91): False,
#    ('hello', 91): False,
#    ('cry', 91): False,
#    ('sweet', 90): False,
#    ('book', 90): False,
#    ('tv', 90): False,
#    ('lunch', 90): False,
#    ('saturday', 90): False,
#    ('stay', 89): False,
#    ('welcome', 89): False,
#    ('poor', 88): False,
#    ('buy', 87): False,
#    ('win', 87): False,
#    ('tho', 87): False,
#    ('face', 86): False,
#    ('eating', 86): False,
#    ('mine', 86): False,
#    ('everything', 86): False,
#    ('without', 86): False,
#    ('wanted', 85): False,
#    ('part', 85): False,
#    ('totally', 84): False,
#    ('name', 84): False,
#    ('soo', 84): False,
#    ('eye', 83): False,
#    ('used', 83): False,
#    ('dog', 82): False,
#    ('room', 82): False,
#    ('xx', 82): False,
#    ('till', 82): False,
#    ('busy', 82): False,
#    ('minute', 81): False,
#    ('ill', 81): False,
#    ('free', 81): False,
#    ('seen', 80): False,
#    ('hell', 80): False,
#    ('okay', 80): False,
#    ('st', 79): False,
#    ('final', 79): False,
#    ('watched', 79): False,
#    ('outside', 79): False,
#    ('didnt', 79): False,
#    ('trip', 79): False,
#    ('lovely', 79): False,
#    ('office', 78): False,
#    ('enough', 78): False,
#    ('kinda', 78): False,
#    ('post', 78): False,
#    ('headache', 78): False,
#    ('believe', 77): False,
#    ('stupid', 77): False,
#    ('money', 77): False,
#    ('crazy', 77): False,
#    ('taking', 76): False,
#    ('remember', 76): False,
#    ('heard', 75): False,
#    ('reply', 75): False,
#    ('anymore', 75): False,
#    ('wrong', 75): False,
#    ('idea', 75): False,
#    ('following', 75): False,
#    ('plan', 75): False,
#    ('beach', 74): False,
#    ('goodnight', 74): False,
#    ('e', 74): False,
#    ('fuck', 73): False,
#    ('hahaha', 73): False,
#    ('mileycyrus', 73): False,
#    ('hopefully', 73): False,
#    ('season', 73): False,
#    ('came', 72): False,
#    ('sitting', 72): False,
#    ('coffee', 72): False,
#    ('whole', 71): False,
#    ('hehe', 71): False,
#    ('stuck', 70): False,
#    ('full', 70): False,
#    ('break', 70): False,
#    ('text', 69): False,
#    ('able', 69): False,
#    ('dad', 68): False,
#    ('half', 68): False,
#    ('pm', 68): False,
#    ('probably', 67): False,
#    ('nite', 67): False,
#    ('shower', 67): False,
#    ('shopping', 67): False,
#    ('run', 66): False,
#    ('award', 66): False,
#    ('started', 66): False,
#    ('rest', 66): False,
#    ('k', 66): False,
#    ('g', 66): False,
#    ('blog', 66): False,
#    ('else', 66): False,
#    ('computer', 65): False,
#    ('quite', 65): False,
#    ('forgot', 65): False,
#    ('dude', 65): False,
#    ('hand', 65): False,
#    ('ah', 65): False,
#    ('tried', 65): False,
#    ('train', 64): False,
#    ('hug', 64): False,
#    ('alone', 64): False,
#    ('btw', 63): False,
#    ('wont', 63): False,
#    ('cat', 63): False,
#    ('enjoying', 63): False,
#    ('reading', 63): False,
#    ('boring', 63): False,
#    ('lucky', 63): False,
#    ('rock', 62): False,
#    ('open', 62): False,
#    ('link', 62): False,
#    ('wake', 62): False,
#    ('la', 62): False,
#    ('page', 61): False,
#    ('photo', 61): False,
#    ('either', 61): False,
#    ('sigh', 61): False,
#    ('yea', 61): False,
#    ('boo', 60): False,
#    ('turn', 60): False,
#    ('meet', 60): False,
#    ('raining', 60): False,
#    ('crap', 60): False,
#    ('kind', 59): False,
#    ('course', 59): False,
#    ('heart', 59): False,
#    ('site', 59): False,
#    ('hit', 59): False,
#    ('leaving', 59): False,
#    ('facebook', 59): False,
#    ('breakfast', 59): False,
#    ('send', 58): False,
#    ('fine', 58): False,
#    ('l', 58): False,
#    ('ago', 58): False,
#    ('true', 58): False,
#    ('problem', 58): False,
#    ('june', 57): False,
#    ('seeing', 57): False,
#    ('hungry', 57): False,
#    ('mr', 57): False,
#    ('afternoon', 57): False,
#    ('super', 57): False,
#    ('cuz', 57): False,
#    ('mum', 56): False,
#    ('favorite', 56): False,
#    ('listen', 56): False,
#    ('internet', 56): False,
#    ('high', 56): False,
#    ('add', 56): False,
#    ('asleep', 56): False,
#    ('concert', 56): False,
#    ('happened', 56): False,
#    ('air', 56): False,
#    ('evening', 56): False,
#    ('story', 55): False,
#    ('move', 55): False,
#    ('hoping', 55): False,
#    ('drink', 55): False,
#    ('nd', 55): False,
#    ('news', 55): False,
#    ('using', 55): False,
#    ('starting', 55): False,
#    ('loved', 55): False,
#    ('com', 55): False,
#    ('line', 54): False,
#    ('test', 54): False,
#    ('lmao', 54): False,
#    ('homework', 54): False,
#    ('sister', 54): False,
#    ('city', 54): False,
#    ('seems', 54): False,
#    ('died', 53): False,
#    ('smile', 53): False,
#    ('awake', 53): False,
#    ('broke', 53): False,
#    ('ticket', 53): False,
#    ('second', 53): False,
#    ('care', 53): False,
#    ('town', 52): False,
#    ('h', 52): False,
#    ('change', 52): False,
#    ('sleeping', 52): False,
#    ('study', 52): False,
#    ('tommcfly', 51): False,
#    ('mind', 51): False,
#    ('told', 51): False,
#    ('til', 51): False,
#    ('park', 51): False,
#    ('ride', 51): False,
#    ('email', 51): False,
#    ('seriously', 50): False,
#    ('v', 50): False,
#    ('catch', 50): False,
#    ('xd', 50): False,
#    ('heading', 50): False,
#    ('studying', 50): False,
#    ('gym', 50): False,
#    ('dear', 50): False,
#    ('set', 50): False,
#    ('meeting', 50): False,
#    ('write', 50): False,
#    ('jonas', 50): False,
#    ('agree', 50): False,
#    ('pain', 50): False,
#    ('sore', 49): False,
#    ('close', 49): False,
#    ('voice', 49): False,
#    ('red', 49): False,
#    ('sometimes', 49): False,
#    ('walk', 49): False,
#    ('couple', 49): False,
#    ('black', 49): False,
#    ('online', 49): False,
#    ('sunny', 48): False,
#    ('pay', 48): False,
#    ('pool', 48): False,
#    ('store', 48): False,
#    ('dead', 48): False,
#    ('ice', 47): False,
#    ('talking', 47): False,
#    ('laptop', 47): False,
#    ('happen', 47): False,
#    ('drive', 47): False,
#    ('bring', 47): False,
#    ('min', 47): False,
#    ('hang', 47): False,
#    ('bought', 47): False,
#    ('account', 47): False,
#    ('ive', 47): False,
#    ('jealous', 47): False,
#    ('lady', 47): False,
#    ('foot', 47): False,
#    ('ipod', 46): False,
#    ('answer', 46): False,
#    ('vote', 46): False,
#    ('list', 46): False,
#    ('lil', 46): False,
#    ('wishing', 46): False,
#    ('flight', 46): False,
#    ('slow', 46): False,
#    ('bus', 46): False,
#    ('tweeting', 45): False,
#    ('wonderful', 45): False,
#    ('fail', 45): False,
#    ('chocolate', 45): False,
#    ('tea', 45): False,
#    ('bday', 45): False,
#    ('cleaning', 45): False,
#    ('fall', 45): False,
#    ('ate', 45): False,
#    ('number', 45): False,
#    ('worth', 45): False,
#    ('aw', 44): False,
#    ('ask', 44): False,
#    ('together', 44): False,
#    ('called', 44): False,
#    ('church', 44): False,
#    ('inside', 44): False,
#    ('cut', 44): False,
#    ('date', 44): False,
#    ('youtube', 44): False,
#    ('fb', 44): False,
#    ('goin', 44): False,
#    ('forget', 44): False,
#    ('note', 43): False,
#    ('visit', 43): False,
#    ('three', 43): False,
#    ('window', 43): False,
#    ('math', 43): False,
#    ('tour', 43): False,
#    ('cheer', 43): False,
#    ('anyway', 43): False,
#    ('short', 43): False,
#    ('scared', 43): False,
#    ('holiday', 43): False,
#    ('cream', 42): False,
#    ('reason', 42): False,
#    ('apparently', 42): False,
#    ('finish', 42): False,
#    ('bout', 42): False,
#    ('soooo', 42): False,
#    ('episode', 42): False,
#    ('awww', 42): False,
#    ('weird', 42): False,
#    ('age', 42): False,
#    ('ahhh', 42): False,
#    ('ddlovato', 42): False,
#    ('learn', 41): False,
#    ('album', 41): False,
#    ('writing', 41): False,
#    ('le', 41): False,
#    ('bye', 41): False,
#    ('seem', 41): False,
#    ('shame', 41): False,
#    ('clean', 41): False,
#    ('side', 41): False,
#    ('shoe', 41): False,
#    ('mac', 40): False,
#    ('rather', 40): False,
#    ('worry', 40): False,
#    ('july', 40): False,
#    ('point', 40): False,
#    ('ppl', 40): False,
#    ('chance', 40): False,
#    ('nap', 40): False,
#    ('mad', 40): False,
#    ('team', 40): False,
#    ('congrats', 40): False,
#    ('sunshine', 40): False,
#    ('person', 40): False,
#    ('sent', 39): False,
#    ('top', 39): False,
#    ('wear', 39): False,
#    ('radio', 39): False,
#    ('definitely', 39): False,
#    ('flu', 39): False,
#    ('instead', 39): False,
#    ('fast', 39): False,
#    ('tuesday', 39): False,
#    ('blue', 38): False,
#    ('f', 38): False,
#    ('star', 38): False,
#    ('london', 38): False,
#    ('english', 38): False,
#    ('shot', 38): False,
#    ('understand', 38): False,
#    ('water', 38): False,
#    ('xxx', 38): False,
#    ('j', 38): False,
#    ('dance', 38): False,
#    ('paper', 37): False,
#    ('si', 37): False,
#    ('band', 37): False,
#    ('slept', 37): False,
#    ('moving', 37): False,
#    ('david', 37): False,
#    ('interesting', 37): False,
#    ('wonder', 37): False,
#    ('easy', 37): False,
#    ('camp', 37): False,
#    ('sleepy', 37): False,
#    ('clothes', 36): False,
#    ('loving', 36): False,
#    ('hangover', 36): False,
#    ('throat', 36): False,
#    ('power', 36): False,
#    ('pick', 36): False,
#    ('nick', 36): False,
#    ('knew', 36): False,
#    ('worst', 36): False,
#    ('service', 36): False,
#    ('ahh', 36): False,
#    ('beer', 36): False,
#    ('unfortunately', 36): False,
#    ('yummy', 36): False,
#    ('broken', 36): False,
#    ('yep', 36): False,
#    ('running', 36): False,
#    ('doesnt', 36): False,
#    ('parent', 36): False,
#    ('moon', 35): False,
#    ('woman', 35): False,
#    ('fell', 35): False,
#    ('supposed', 35): False,
#    ('followfriday', 35): False,
#    ('miley', 35): False,
#    ('join', 35): False,
#    ('fix', 35): False,
#    ('bitch', 35): False,
#    ('hubby', 35): False,
#    ('perfect', 35): False,
#    ('wtf', 35): False,
#    ('nope', 34): False,
#    ('angel', 34): False,
#    ('thx', 34): False,
#    ('xoxo', 34): False,
#    ('random', 34): False,
#    ('pas', 34): False,
#    ('project', 34): False,
#    ('horrible', 34): False,
#    ('boyfriend', 34): False,
#    ('dm', 34): False,
#    ('hr', 34): False,
#    ('bet', 34): False,
#    ('em', 34): False,
#    ('hmmm', 33): False,
#    ('doctor', 33): False,
#    ('mtv', 33): False,
#    ('special', 33): False,
#    ('da', 33): False,
#    ('shirt', 33): False,
#    ('felt', 33): False,
#    ('wine', 33): False,
#    ('mood', 33): False,
#    ('storm', 33): False,
#    ('question', 33): False,
#    ('ring', 33): False,
#    ('lonely', 33): False,
#    ('spend', 33): False,
#    ('yr', 33): False,
#    ('whatever', 33): False,
#    ('hmm', 32): False,
#    ('cake', 32): False,
#    ('havent', 32): False,
#    ('watchin', 32): False,
#    ('driving', 32): False,
#    ('gave', 32): False,
#    ('plus', 32): False,
#    ('via', 32): False,
#    ('country', 32): False,
#    ('wedding', 32): False,
#    ('forever', 32): False,
#    ('order', 32): False,
#    ('chat', 32): False,
#    ('light', 32): False,
#    ('bike', 32): False,
#    ('everybody', 32): False,
#    ('joe', 31): False,
#    ('message', 31): False,
#    ('drinking', 31): False,
#    ('load', 31): False,
#    ('along', 31): False,
#    ('fml', 31): False,
#    ('vacation', 31): False,
#    ('fair', 31): False,
#    ('apple', 31): False,
#    ('camera', 31): False,
#    ('ouch', 31): False,
#    ('sat', 31): False,
#    ('garden', 31): False,
#    ('bbq', 31): False,
#    ('past', 31): False,
#    ('babe', 31): False,
#    ('lakers', 31): False,
#    ('green', 31): False,
#    ('result', 31): False,
#    ('revision', 30): False,
#    ('asked', 30): False,
#    ('mail', 30): False,
#    ('gorgeous', 30): False,
#    ('wondering', 30): False,
#    ('jus', 30): False,
#    ('worried', 30): False,
#    ('puppy', 30): False,
#    ('honey', 30): False,
#    ('exactly', 30): False,
#    ('bloody', 30): False,
#    ('single', 30): False,
#    ('leg', 30): False,
#    ('moment', 30): False,
#    ('shoot', 30): False,
#    ('thursday', 30): False,
#    ('wit', 30): False,
#    ('disappointed', 30): False,
#    ('saying', 30): False,
#    ('fly', 30): False,
#    ('dress', 30): False,
#    ('demi', 30): False,
#    ('bag', 30): False,
#    ('alright', 30): False,
#    ('blah', 30): False,
#    ('goodbye', 30): False,
#    ('spent', 29): False,
#    ('played', 29): False,
#    ('front', 29): False,
#    ('fact', 29): False,
#    ('walking', 29): False,
#    ('sale', 29): False,
#    ('matter', 29): False,
#    ('cover', 29): False,
#    ('beat', 29): False,
#    ('app', 29): False,
#    ('body', 29): False,
#    ('ooh', 29): False,
#    ('box', 29): False,
#    ('guitar', 29): False,
#    ('absolutely', 29): False,
#    ('mommy', 29): False,
#    ('hanging', 29): False,
#    ('relaxing', 29): False,
#    ('passed', 29): False,
#    ('tummy', 29): False,
#    ('uk', 29): False,
#    ('eh', 29): False,
#    ('due', 29): False,
#    ('upset', 29): False,
#    ('kill', 29): False,
#    ('living', 29): False,
#    ('french', 29): False,
#    ('killing', 29): False,
#    ('record', 29): False,
#    ('longer', 29): False,
#    ('whats', 29): False,
#    ('near', 29): False,
#    ('traffic', 29): False,
#    ('co', 29): False,
#    ('touch', 28): False,
#    ('figure', 28): False,
#    ('arm', 28): False,
#    ('turned', 28): False,
#    ('group', 28): False,
#    ('share', 28): False,
#    ('different', 28): False,
#    ('posted', 28): False,
#    ('hill', 28): False,
#    ('fit', 28): False,
#    ('sign', 28): False,
#    ('warm', 28): False,
#    ('wet', 28): False,
#    ('bummed', 28): False,
#    ('worked', 28): False,
#    ('safe', 28): False,
#    ('website', 28): False,
#    ('comment', 28): False,
#    ('lazy', 28): False,
#    ('smell', 28): False,
#    ('fucking', 28): False,
#    ('trailer', 28): False,
#    ('card', 28): False,
#    ('hospital', 28): False,
#    ('xo', 28): False,
#    ('john', 28): False,
#    ('ohh', 28): False,
#    ('stand', 27): False,
#    ('case', 27): False,
#    ('jonasbrothers', 27): False,
#    ('father', 27): False,
#    ('singing', 27): False,
#    ('freaking', 27): False,
#    ('art', 27): False,
#    ('cup', 27): False,
#    ('club', 27): False,
#    ('pizza', 27): False,
#    ('rainy', 27): False,
#    ('version', 27): False,
#    ('packing', 27): False,
#    ('ache', 27): False,
#    ('die', 27): False,
#    ('airport', 27): False,
#    ('magic', 27): False,
#    ('yup', 27): False,
#    ('deal', 27): False,
#    ('officially', 27): False,
#    ('white', 27): False,
#    ('looked', 27): False,
#    ('drunk', 27): False,
#    ('door', 27): False,
#    ('rip', 27): False,
#    ('earlier', 27): False,
#    ('shop', 26): False,
#    ('ball', 26): False,
#    ('hold', 26): False,
#    ('chris', 26): False,
#    ('ear', 26): False,
#    ('dark', 26): False,
#    ('except', 26): False,
#    ('company', 26): False,
#    ('silly', 26): False,
#    ('stomach', 26): False,
#    ('round', 26): False,
#    ('failed', 26): False,
#    ('proud', 26): False,
#    ('joy', 26): False,
#    ('chicken', 26): False,
#    ('dvd', 26): False,
#    ('business', 26): False,
#    ('hun', 26): False,
#    ('dying', 26): False,
#    ('glass', 26): False,
#    ('tear', 26): False,
#    ('web', 26): False,
#    ('aint', 26): False,
#    ('promise', 26): False,
#    ('huge', 26): False,
#    ('profile', 25): False,
#    ('self', 25): False,
#    ('graduation', 25): False,
#    ('woo', 25): False,
#    ('happens', 25): False,
#    ('tom', 25): False,
#    ('asking', 25): False,
#    ('although', 25): False,
#    ('son', 25): False,
#    ('lame', 25): False,
#    ('awful', 25): False,
#    ('sum', 25): False,
#    ('wednesday', 25): False,
#    ('track', 25): False,
#    ('event', 25): False,
#    ('bro', 25): False,
#    ('type', 25): False,
#    ('behind', 25): False,
#    ('trouble', 25): False,
#    ('twilight', 25): False,
#    ('idk', 25): False,
#    ('spending', 25): False,
#    ('sims', 25): False,
#    ('pc', 25): False,
#    ('american', 25): False,
#    ('rd', 25): False,
#    ('decided', 25): False,
#    ('studio', 24): False,
#    ('straight', 24): False,
#    ('google', 24): False,
#    ('yo', 24): False,
#    ('vega', 24): False,
#    ('gettin', 24): False,
#    ('nobody', 24): False,
#    ('mile', 24): False,
#    ('vip', 24): False,
#    ('enjoyed', 24): False,
#    ('sadly', 24): False,
#    ('wat', 24): False,
#    ('teacher', 24): False,
#    ('taylor', 24): False,
#    ('sarah', 24): False,
#    ('match', 24): False,
#    ('met', 24): False,
#    ('needed', 24): False,
#    ('mcfly', 24): False,
#    ('coz', 24): False,
#    ('ended', 24): False,
#    ('de', 24): False,
#    ('support', 24): False,
#    ('id', 24): False,
#    ('myspace', 24): False,
#    ('cook', 24): False,
#    ('cd', 24): False,
#    ('usually', 24): False,
#    ('screen', 24): False,
#    ('alex', 24): False,
#    ('film', 24): False,
#    ('interview', 24): False,
#    ('france', 24): False,
#    ('currently', 24): False,
#    ('normal', 24): False,
#    ('laugh', 24): False,
#    ('cheese', 24): False,
#    ('sexy', 23): False,
#    ('nose', 23): False,
#    ('report', 23): False,
#    ('worse', 23): False,
#    ('major', 23): False,
#    ('south', 23): False,
#    ('tan', 23): False,
#    ('sort', 23): False,
#    ('meant', 23): False,
#    ('wife', 23): False,
#    ('couch', 23): False,
#    ('luv', 23): False,
#    ('gig', 23): False,
#    ('mmm', 23): False,
#    ('delicious', 23): False,
#    ('ton', 23): False,
#    ('sold', 23): False,
#    ('ahead', 23): False,
#    ('tree', 23): False,
#    ('count', 23): False,
#    ('low', 23): False,
#    ('upload', 23): False,
#    ('plane', 23): False,
#    ('college', 23): False,
#    ('bb', 23): False,
#    ('annoying', 23): False,
#    ('positive', 23): False,
#    ('especially', 23): False,
#    ('finger', 22): False,
#    ('talent', 22): False,
#    ('crash', 22): False,
#    ('def', 22): False,
#    ('ny', 22): False,
#    ('return', 22): False,
#    ('tip', 22): False,
#    ('arrived', 22): False,
#    ('hahah', 22): False,
#    ('nyc', 22): False,
#    ('ran', 22): False,
#    ('isnt', 22): False,
#    ('daughter', 22): False,
#    ('scary', 22): False,
#    ('healthy', 22): False,
#    ('depressed', 22): False,
#    ('teeth', 22): False,
#    ('knee', 22): False,
#    ('chillin', 22): False,
#    ('street', 22): False,
#    ('hotel', 22): False,
#    ('completely', 22): False,
#    ('indeed', 22): False,
#    ('cousin', 22): False,
#    ('waking', 22): False,
#    ('exciting', 22): False,
#    ('mi', 22): False,
#    ('alot', 22): False,
#    ('pink', 22): False,
#    ('changed', 22): False,
#    ('degree', 22): False,
#    ('finding', 22): False,
#    ('soccer', 22): False,
#    ('finishing', 22): False,
#    ('yall', 22): False,
#    ('bank', 22): False,
#    ('kiss', 22): False,
#    ('click', 22): False,
#    ('shut', 22): False,
#    ('liked', 22): False,
#    ('butt', 22): False,
#    ('state', 22): False,
#    ('terrible', 22): False,
#    ('fat', 21): False,
#    ('killed', 21): False,
#    ('ff', 21): False,
#    ('drop', 21): False,
#    ('shift', 21): False,
#    ('download', 21): False,
#    ('festival', 21): False,
#    ('contact', 21): False,
#    ...},
#   0),
#  ({('day', 1434): False,
#    ('wa', 1269): False,
#    ('good', 1189): False,
#    ('go', 1071): False,
#    ('get', 1063): False,
#    ('like', 984): False,
#    ('quot', 982): False,
#    ('got', 935): False,
#    ('today', 883): False,
#    ('u', 850): False,
#    ('love', 847): False,
#    ('going', 837): False,
#    ('time', 837): False,
#    ('work', 832): False,
#    ('back', 743): False,
#    ('know', 696): False,
#    ('lol', 695): False,
#    ('one', 675): False,
#    ('really', 642): False,
#    ('im', 634): False,
#    ('night', 630): False,
#    ('want', 623): False,
#    ('amp', 618): False,
#    ('still', 572): False,
#    ('see', 566): False,
#    ('na', 545): False,
#    ('home', 540): False,
#    ('new', 529): False,
#    ('well', 513): False,
#    ('think', 510): False,
#    ('miss', 507): False,
#    ('thanks', 503): False,
#    ('need', 499): False,
#    ('last', 493): False,
#    ('ha', 484): False,
#    ('oh', 451): False,
#    ('morning', 450): False,
#    ('hope', 445): False,
#    ('feel', 434): False,
#    ('much', 430): False,
#    ('make', 424): False,
#    ('tomorrow', 424): False,
#    ('twitter', 410): False,
#    ('great', 405): False,
#    ('haha', 392): False,
#    ('wish', 381): False,
#    ('friend', 379): False,
#    ('come', 360): False,
#    ('happy', 357): False,
#    ('fun', 356): False,
#    ('sad', 355): False,
#    ('thing', 344): False,
#    ('right', 344): False,
#    ('would', 338): False,
#    ('week', 327): False,
#    ('bad', 326): False,
#    ('sorry', 320): False,
#    ('sleep', 318): False,
#    ('getting', 318): False,
#    ('tonight', 316): False,
#    ('gon', 313): False,
#    ('though', 308): False,
#    ('watching', 301): False,
#    ('bed', 301): False,
#    ('look', 299): False,
#    ('way', 295): False,
#    ('nice', 295): False,
#    ('better', 289): False,
#    ('guy', 289): False,
#    ('say', 285): False,
#    ('yeah', 283): False,
#    ('hate', 276): False,
#    ('could', 269): False,
#    ('school', 265): False,
#    ('show', 263): False,
#    ('wait', 258): False,
#    ('girl', 252): False,
#    ('lt', 249): False,
#    ('people', 247): False,
#    ('hey', 243): False,
#    ('hour', 242): False,
#    ('tired', 241): False,
#    ('yes', 241): False,
#    ('weekend', 238): False,
#    ('x', 236): False,
#    ('movie', 236): False,
#    ('take', 235): False,
#    ('dont', 234): False,
#    ('never', 230): False,
#    ('tweet', 229): False,
#    ('first', 227): False,
#    ('even', 226): False,
#    ('next', 226): False,
#    ('long', 224): False,
#    ('awesome', 222): False,
#    ('life', 221): False,
#    ('watch', 219): False,
#    ('soon', 218): False,
#    ('working', 218): False,
#    ('let', 215): False,
#    ('done', 215): False,
#    ('thank', 215): False,
#    ('everyone', 213): False,
#    ('wan', 213): False,
#    ('best', 212): False,
#    ('please', 208): False,
#    ('sick', 207): False,
#    ('ur', 206): False,
#    ('suck', 204): False,
#    ('ready', 201): False,
#    ('find', 200): False,
#    ('cant', 194): False,
#    ('feeling', 194): False,
#    ('already', 193): False,
#    ('another', 193): False,
#    ('year', 191): False,
#    ('cool', 190): False,
#    ('b', 189): False,
#    ('looking', 188): False,
#    ('little', 187): False,
#    ('summer', 186): False,
#    ('yay', 183): False,
#    ('sure', 182): False,
#    ('ok', 181): False,
#    ('help', 181): False,
#    ('lot', 179): False,
#    ('phone', 174): False,
#    ('n', 173): False,
#    ('something', 173): False,
#    ('ever', 173): False,
#    ('keep', 170): False,
#    ('hurt', 169): False,
#    ('song', 166): False,
#    ('thought', 166): False,
#    ('trying', 164): False,
#    ('went', 164): False,
#    ('always', 163): False,
#    ('damn', 162): False,
#    ('yet', 161): False,
#    ('house', 159): False,
#    ('someone', 156): False,
#    ('hot', 156): False,
#    ('made', 156): False,
#    ('pretty', 155): False,
#    ('amazing', 155): False,
#    ('guess', 153): False,
#    ('missed', 151): False,
#    ('rain', 150): False,
#    ('lost', 149): False,
#    ('sound', 148): False,
#    ('big', 148): False,
#    ('baby', 147): False,
#    ('ta', 147): False,
#    ('finally', 147): False,
#    ('w', 147): False,
#    ('wow', 147): False,
#    ('start', 146): False,
#    ('call', 145): False,
#    ('old', 144): False,
#    ('follow', 144): False,
#    ('early', 143): False,
#    ('ya', 143): False,
#    ('said', 143): False,
#    ('away', 141): False,
#    ('stuff', 140): False,
#    ('glad', 140): False,
#    ('game', 139): False,
#    ('maybe', 139): False,
#    ('p', 139): False,
#    ('ugh', 139): False,
#    ('actually', 139): False,
#    ('try', 138): False,
#    ('pic', 137): False,
#    ('tell', 137): False,
#    ('omg', 137): False,
#    ('man', 136): False,
#    ('god', 136): False,
#    ('nothing', 136): False,
#    ('yesterday', 135): False,
#    ('bit', 135): False,
#    ('left', 135): False,
#    ('two', 133): False,
#    ('car', 132): False,
#    ('mom', 132): False,
#    ('also', 132): False,
#    ('weather', 132): False,
#    ('sun', 131): False,
#    ('th', 131): False,
#    ('waiting', 130): False,
#    ('saw', 130): False,
#    ('around', 128): False,
#    ('birthday', 126): False,
#    ('sunday', 126): False,
#    ('mean', 125): False,
#    ('live', 125): False,
#    ('give', 125): False,
#    ('bored', 125): False,
#    ('excited', 124): False,
#    ('party', 124): False,
#    ('later', 124): False,
#    ('luck', 124): False,
#    ('since', 123): False,
#    ('stop', 122): False,
#    ('coming', 122): False,
#    ('friday', 122): False,
#    ('might', 121): False,
#    ('kid', 121): False,
#    ('aww', 120): False,
#    ('doe', 120): False,
#    ('play', 120): False,
#    ('many', 119): False,
#    ('music', 118): False,
#    ('hear', 118): False,
#    ('r', 115): False,
#    ('thats', 114): False,
#    ('world', 114): False,
#    ('late', 114): False,
#    ('talk', 113): False,
#    ('job', 112): False,
#    ('hard', 112): False,
#    ('exam', 112): False,
#    ('monday', 111): False,
#    ('cold', 111): False,
#    ('video', 110): False,
#    ('head', 110): False,
#    ('use', 110): False,
#    ('funny', 109): False,
#    ('must', 109): False,
#    ('boy', 109): False,
#    ('mother', 109): False,
#    ('follower', 108): False,
#    ('check', 108): False,
#    ('making', 106): False,
#    ('listening', 105): False,
#    ('put', 104): False,
#    ('woke', 104): False,
#    ('found', 104): False,
#    ('forward', 103): False,
#    ('cute', 103): False,
#    ('finished', 103): False,
#    ('hi', 102): False,
#    ('hair', 102): False,
#    ('anyone', 102): False,
#    ('gone', 102): False,
#    ('thinking', 102): False,
#    ('cause', 101): False,
#    ('far', 101): False,
#    ('beautiful', 101): False,
#    ('least', 99): False,
#    ('read', 99): False,
#    ('leave', 99): False,
#    ('dinner', 99): False,
#    ('enjoy', 99): False,
#    ('food', 99): False,
#    ('word', 98): False,
#    ('anything', 98): False,
#    ('iphone', 98): False,
#    ('real', 98): False,
#    ('may', 98): False,
#    ('picture', 98): False,
#    ('missing', 97): False,
#    ('family', 97): False,
#    ('shit', 97): False,
#    ('month', 96): False,
#    ('fan', 96): False,
#    ('dream', 96): False,
#    ('eat', 96): False,
#    ('class', 95): False,
#    ('sooo', 95): False,
#    ('playing', 95): False,
#    ('every', 94): False,
#    ('update', 94): False,
#    ('gt', 94): False,
#    ('c', 93): False,
#    ('end', 93): False,
#    ('place', 93): False,
#    ('took', 92): False,
#    ('almost', 92): False,
#    ('brother', 91): False,
#    ('hello', 91): False,
#    ('cry', 91): False,
#    ('sweet', 90): False,
#    ('book', 90): False,
#    ('tv', 90): False,
#    ('lunch', 90): False,
#    ('saturday', 90): False,
#    ('stay', 89): False,
#    ('welcome', 89): False,
#    ('poor', 88): False,
#    ('buy', 87): False,
#    ('win', 87): False,
#    ('tho', 87): False,
#    ('face', 86): False,
#    ('eating', 86): False,
#    ('mine', 86): False,
#    ('everything', 86): False,
#    ('without', 86): False,
#    ('wanted', 85): False,
#    ('part', 85): False,
#    ('totally', 84): False,
#    ('name', 84): False,
#    ('soo', 84): False,
#    ('eye', 83): False,
#    ('used', 83): False,
#    ('dog', 82): False,
#    ('room', 82): False,
#    ('xx', 82): False,
#    ('till', 82): False,
#    ('busy', 82): False,
#    ('minute', 81): False,
#    ('ill', 81): False,
#    ('free', 81): False,
#    ('seen', 80): False,
#    ('hell', 80): False,
#    ('okay', 80): False,
#    ('st', 79): False,
#    ('final', 79): False,
#    ('watched', 79): False,
#    ('outside', 79): False,
#    ('didnt', 79): False,
#    ('trip', 79): False,
#    ('lovely', 79): False,
#    ('office', 78): False,
#    ('enough', 78): False,
#    ('kinda', 78): False,
#    ('post', 78): False,
#    ('headache', 78): False,
#    ('believe', 77): False,
#    ('stupid', 77): False,
#    ('money', 77): False,
#    ('crazy', 77): False,
#    ('taking', 76): False,
#    ('remember', 76): False,
#    ('heard', 75): False,
#    ('reply', 75): False,
#    ('anymore', 75): False,
#    ('wrong', 75): False,
#    ('idea', 75): False,
#    ('following', 75): False,
#    ('plan', 75): False,
#    ('beach', 74): False,
#    ('goodnight', 74): False,
#    ('e', 74): False,
#    ('fuck', 73): False,
#    ('hahaha', 73): False,
#    ('mileycyrus', 73): False,
#    ('hopefully', 73): False,
#    ('season', 73): False,
#    ('came', 72): False,
#    ('sitting', 72): False,
#    ('coffee', 72): False,
#    ('whole', 71): False,
#    ('hehe', 71): False,
#    ('stuck', 70): False,
#    ('full', 70): False,
#    ('break', 70): False,
#    ('text', 69): False,
#    ('able', 69): False,
#    ('dad', 68): False,
#    ('half', 68): False,
#    ('pm', 68): False,
#    ('probably', 67): False,
#    ('nite', 67): False,
#    ('shower', 67): False,
#    ('shopping', 67): False,
#    ('run', 66): False,
#    ('award', 66): False,
#    ('started', 66): False,
#    ('rest', 66): False,
#    ('k', 66): False,
#    ('g', 66): False,
#    ('blog', 66): False,
#    ('else', 66): False,
#    ('computer', 65): False,
#    ('quite', 65): False,
#    ('forgot', 65): False,
#    ('dude', 65): False,
#    ('hand', 65): False,
#    ('ah', 65): False,
#    ('tried', 65): False,
#    ('train', 64): False,
#    ('hug', 64): False,
#    ('alone', 64): False,
#    ('btw', 63): False,
#    ('wont', 63): False,
#    ('cat', 63): False,
#    ('enjoying', 63): False,
#    ('reading', 63): False,
#    ('boring', 63): False,
#    ('lucky', 63): False,
#    ('rock', 62): False,
#    ('open', 62): False,
#    ('link', 62): False,
#    ('wake', 62): False,
#    ('la', 62): False,
#    ('page', 61): False,
#    ('photo', 61): False,
#    ('either', 61): False,
#    ('sigh', 61): False,
#    ('yea', 61): False,
#    ('boo', 60): False,
#    ('turn', 60): False,
#    ('meet', 60): False,
#    ('raining', 60): False,
#    ('crap', 60): False,
#    ('kind', 59): False,
#    ('course', 59): False,
#    ('heart', 59): False,
#    ('site', 59): False,
#    ('hit', 59): False,
#    ('leaving', 59): False,
#    ('facebook', 59): False,
#    ('breakfast', 59): False,
#    ('send', 58): False,
#    ('fine', 58): False,
#    ('l', 58): False,
#    ('ago', 58): False,
#    ('true', 58): False,
#    ('problem', 58): False,
#    ('june', 57): False,
#    ('seeing', 57): False,
#    ('hungry', 57): False,
#    ('mr', 57): False,
#    ('afternoon', 57): False,
#    ('super', 57): False,
#    ('cuz', 57): False,
#    ('mum', 56): False,
#    ('favorite', 56): False,
#    ('listen', 56): False,
#    ('internet', 56): False,
#    ('high', 56): False,
#    ('add', 56): False,
#    ('asleep', 56): False,
#    ('concert', 56): False,
#    ('happened', 56): False,
#    ('air', 56): False,
#    ('evening', 56): False,
#    ('story', 55): False,
#    ('move', 55): False,
#    ('hoping', 55): False,
#    ('drink', 55): False,
#    ('nd', 55): False,
#    ('news', 55): False,
#    ('using', 55): False,
#    ('starting', 55): False,
#    ('loved', 55): False,
#    ('com', 55): False,
#    ('line', 54): False,
#    ('test', 54): False,
#    ('lmao', 54): False,
#    ('homework', 54): False,
#    ('sister', 54): False,
#    ('city', 54): False,
#    ('seems', 54): False,
#    ('died', 53): False,
#    ('smile', 53): False,
#    ('awake', 53): False,
#    ('broke', 53): False,
#    ('ticket', 53): False,
#    ('second', 53): False,
#    ('care', 53): False,
#    ('town', 52): False,
#    ('h', 52): False,
#    ('change', 52): False,
#    ('sleeping', 52): False,
#    ('study', 52): False,
#    ('tommcfly', 51): False,
#    ('mind', 51): False,
#    ('told', 51): False,
#    ('til', 51): False,
#    ('park', 51): False,
#    ('ride', 51): False,
#    ('email', 51): False,
#    ('seriously', 50): False,
#    ('v', 50): False,
#    ('catch', 50): False,
#    ('xd', 50): False,
#    ('heading', 50): False,
#    ('studying', 50): False,
#    ('gym', 50): False,
#    ('dear', 50): False,
#    ('set', 50): False,
#    ('meeting', 50): False,
#    ('write', 50): False,
#    ('jonas', 50): False,
#    ('agree', 50): False,
#    ('pain', 50): False,
#    ('sore', 49): False,
#    ('close', 49): False,
#    ('voice', 49): False,
#    ('red', 49): False,
#    ('sometimes', 49): False,
#    ('walk', 49): False,
#    ('couple', 49): False,
#    ('black', 49): False,
#    ('online', 49): False,
#    ('sunny', 48): False,
#    ('pay', 48): False,
#    ('pool', 48): False,
#    ('store', 48): False,
#    ('dead', 48): False,
#    ('ice', 47): False,
#    ('talking', 47): False,
#    ('laptop', 47): False,
#    ('happen', 47): False,
#    ('drive', 47): False,
#    ('bring', 47): False,
#    ('min', 47): False,
#    ('hang', 47): False,
#    ('bought', 47): False,
#    ('account', 47): False,
#    ('ive', 47): False,
#    ('jealous', 47): False,
#    ('lady', 47): False,
#    ('foot', 47): False,
#    ('ipod', 46): False,
#    ('answer', 46): False,
#    ('vote', 46): False,
#    ('list', 46): False,
#    ('lil', 46): False,
#    ('wishing', 46): False,
#    ('flight', 46): False,
#    ('slow', 46): False,
#    ('bus', 46): False,
#    ('tweeting', 45): False,
#    ('wonderful', 45): False,
#    ('fail', 45): False,
#    ('chocolate', 45): False,
#    ('tea', 45): False,
#    ('bday', 45): False,
#    ('cleaning', 45): False,
#    ('fall', 45): False,
#    ('ate', 45): False,
#    ('number', 45): False,
#    ('worth', 45): False,
#    ('aw', 44): False,
#    ('ask', 44): False,
#    ('together', 44): False,
#    ('called', 44): False,
#    ('church', 44): False,
#    ('inside', 44): False,
#    ('cut', 44): False,
#    ('date', 44): False,
#    ('youtube', 44): False,
#    ('fb', 44): False,
#    ('goin', 44): False,
#    ('forget', 44): False,
#    ('note', 43): False,
#    ('visit', 43): False,
#    ('three', 43): False,
#    ('window', 43): False,
#    ('math', 43): False,
#    ('tour', 43): False,
#    ('cheer', 43): False,
#    ('anyway', 43): False,
#    ('short', 43): False,
#    ('scared', 43): False,
#    ('holiday', 43): False,
#    ('cream', 42): False,
#    ('reason', 42): False,
#    ('apparently', 42): False,
#    ('finish', 42): False,
#    ('bout', 42): False,
#    ('soooo', 42): False,
#    ('episode', 42): False,
#    ('awww', 42): False,
#    ('weird', 42): False,
#    ('age', 42): False,
#    ('ahhh', 42): False,
#    ('ddlovato', 42): False,
#    ('learn', 41): False,
#    ('album', 41): False,
#    ('writing', 41): False,
#    ('le', 41): False,
#    ('bye', 41): False,
#    ('seem', 41): False,
#    ('shame', 41): False,
#    ('clean', 41): False,
#    ('side', 41): False,
#    ('shoe', 41): False,
#    ('mac', 40): False,
#    ('rather', 40): False,
#    ('worry', 40): False,
#    ('july', 40): False,
#    ('point', 40): False,
#    ('ppl', 40): False,
#    ('chance', 40): False,
#    ('nap', 40): False,
#    ('mad', 40): False,
#    ('team', 40): False,
#    ('congrats', 40): False,
#    ('sunshine', 40): False,
#    ('person', 40): False,
#    ('sent', 39): False,
#    ('top', 39): False,
#    ('wear', 39): False,
#    ('radio', 39): False,
#    ('definitely', 39): False,
#    ('flu', 39): False,
#    ('instead', 39): False,
#    ('fast', 39): False,
#    ('tuesday', 39): False,
#    ('blue', 38): False,
#    ('f', 38): False,
#    ('star', 38): False,
#    ('london', 38): False,
#    ('english', 38): False,
#    ('shot', 38): False,
#    ('understand', 38): False,
#    ('water', 38): False,
#    ('xxx', 38): False,
#    ('j', 38): False,
#    ('dance', 38): False,
#    ('paper', 37): False,
#    ('si', 37): False,
#    ('band', 37): False,
#    ('slept', 37): False,
#    ('moving', 37): False,
#    ('david', 37): False,
#    ('interesting', 37): False,
#    ('wonder', 37): False,
#    ('easy', 37): False,
#    ('camp', 37): False,
#    ('sleepy', 37): False,
#    ('clothes', 36): False,
#    ('loving', 36): False,
#    ('hangover', 36): False,
#    ('throat', 36): False,
#    ('power', 36): False,
#    ('pick', 36): False,
#    ('nick', 36): False,
#    ('knew', 36): False,
#    ('worst', 36): False,
#    ('service', 36): False,
#    ('ahh', 36): False,
#    ('beer', 36): False,
#    ('unfortunately', 36): False,
#    ('yummy', 36): False,
#    ('broken', 36): False,
#    ('yep', 36): False,
#    ('running', 36): False,
#    ('doesnt', 36): False,
#    ('parent', 36): False,
#    ('moon', 35): False,
#    ('woman', 35): False,
#    ('fell', 35): False,
#    ('supposed', 35): False,
#    ('followfriday', 35): False,
#    ('miley', 35): False,
#    ('join', 35): False,
#    ('fix', 35): False,
#    ('bitch', 35): False,
#    ('hubby', 35): False,
#    ('perfect', 35): False,
#    ('wtf', 35): False,
#    ('nope', 34): False,
#    ('angel', 34): False,
#    ('thx', 34): False,
#    ('xoxo', 34): False,
#    ('random', 34): False,
#    ('pas', 34): False,
#    ('project', 34): False,
#    ('horrible', 34): False,
#    ('boyfriend', 34): False,
#    ('dm', 34): False,
#    ('hr', 34): False,
#    ('bet', 34): False,
#    ('em', 34): False,
#    ('hmmm', 33): False,
#    ('doctor', 33): False,
#    ('mtv', 33): False,
#    ('special', 33): False,
#    ('da', 33): False,
#    ('shirt', 33): False,
#    ('felt', 33): False,
#    ('wine', 33): False,
#    ('mood', 33): False,
#    ('storm', 33): False,
#    ('question', 33): False,
#    ('ring', 33): False,
#    ('lonely', 33): False,
#    ('spend', 33): False,
#    ('yr', 33): False,
#    ('whatever', 33): False,
#    ('hmm', 32): False,
#    ('cake', 32): False,
#    ('havent', 32): False,
#    ('watchin', 32): False,
#    ('driving', 32): False,
#    ('gave', 32): False,
#    ('plus', 32): False,
#    ('via', 32): False,
#    ('country', 32): False,
#    ('wedding', 32): False,
#    ('forever', 32): False,
#    ('order', 32): False,
#    ('chat', 32): False,
#    ('light', 32): False,
#    ('bike', 32): False,
#    ('everybody', 32): False,
#    ('joe', 31): False,
#    ('message', 31): False,
#    ('drinking', 31): False,
#    ('load', 31): False,
#    ('along', 31): False,
#    ('fml', 31): False,
#    ('vacation', 31): False,
#    ('fair', 31): False,
#    ('apple', 31): False,
#    ('camera', 31): False,
#    ('ouch', 31): False,
#    ('sat', 31): False,
#    ('garden', 31): False,
#    ('bbq', 31): False,
#    ('past', 31): False,
#    ('babe', 31): False,
#    ('lakers', 31): False,
#    ('green', 31): False,
#    ('result', 31): False,
#    ('revision', 30): False,
#    ('asked', 30): False,
#    ('mail', 30): False,
#    ('gorgeous', 30): False,
#    ('wondering', 30): False,
#    ('jus', 30): False,
#    ('worried', 30): False,
#    ('puppy', 30): False,
#    ('honey', 30): False,
#    ('exactly', 30): False,
#    ('bloody', 30): False,
#    ('single', 30): False,
#    ('leg', 30): False,
#    ('moment', 30): False,
#    ('shoot', 30): False,
#    ('thursday', 30): False,
#    ('wit', 30): False,
#    ('disappointed', 30): False,
#    ('saying', 30): False,
#    ('fly', 30): False,
#    ('dress', 30): False,
#    ('demi', 30): False,
#    ('bag', 30): False,
#    ('alright', 30): False,
#    ('blah', 30): False,
#    ('goodbye', 30): False,
#    ('spent', 29): False,
#    ('played', 29): False,
#    ('front', 29): False,
#    ('fact', 29): False,
#    ('walking', 29): False,
#    ('sale', 29): False,
#    ('matter', 29): False,
#    ('cover', 29): False,
#    ('beat', 29): False,
#    ('app', 29): False,
#    ('body', 29): False,
#    ('ooh', 29): False,
#    ('box', 29): False,
#    ('guitar', 29): False,
#    ('absolutely', 29): False,
#    ('mommy', 29): False,
#    ('hanging', 29): False,
#    ('relaxing', 29): False,
#    ('passed', 29): False,
#    ('tummy', 29): False,
#    ('uk', 29): False,
#    ('eh', 29): False,
#    ('due', 29): False,
#    ('upset', 29): False,
#    ('kill', 29): False,
#    ('living', 29): False,
#    ('french', 29): False,
#    ('killing', 29): False,
#    ('record', 29): False,
#    ('longer', 29): False,
#    ('whats', 29): False,
#    ('near', 29): False,
#    ('traffic', 29): False,
#    ('co', 29): False,
#    ('touch', 28): False,
#    ('figure', 28): False,
#    ('arm', 28): False,
#    ('turned', 28): False,
#    ('group', 28): False,
#    ('share', 28): False,
#    ('different', 28): False,
#    ('posted', 28): False,
#    ('hill', 28): False,
#    ('fit', 28): False,
#    ('sign', 28): False,
#    ('warm', 28): False,
#    ('wet', 28): False,
#    ('bummed', 28): False,
#    ('worked', 28): False,
#    ('safe', 28): False,
#    ('website', 28): False,
#    ('comment', 28): False,
#    ('lazy', 28): False,
#    ('smell', 28): False,
#    ('fucking', 28): False,
#    ('trailer', 28): False,
#    ('card', 28): False,
#    ('hospital', 28): False,
#    ('xo', 28): False,
#    ('john', 28): False,
#    ('ohh', 28): False,
#    ('stand', 27): False,
#    ('case', 27): False,
#    ('jonasbrothers', 27): False,
#    ('father', 27): False,
#    ('singing', 27): False,
#    ('freaking', 27): False,
#    ('art', 27): False,
#    ('cup', 27): False,
#    ('club', 27): False,
#    ('pizza', 27): False,
#    ('rainy', 27): False,
#    ('version', 27): False,
#    ('packing', 27): False,
#    ('ache', 27): False,
#    ('die', 27): False,
#    ('airport', 27): False,
#    ('magic', 27): False,
#    ('yup', 27): False,
#    ('deal', 27): False,
#    ('officially', 27): False,
#    ('white', 27): False,
#    ('looked', 27): False,
#    ('drunk', 27): False,
#    ('door', 27): False,
#    ('rip', 27): False,
#    ('earlier', 27): False,
#    ('shop', 26): False,
#    ('ball', 26): False,
#    ('hold', 26): False,
#    ('chris', 26): False,
#    ('ear', 26): False,
#    ('dark', 26): False,
#    ('except', 26): False,
#    ('company', 26): False,
#    ('silly', 26): False,
#    ('stomach', 26): False,
#    ('round', 26): False,
#    ('failed', 26): False,
#    ('proud', 26): False,
#    ('joy', 26): False,
#    ('chicken', 26): False,
#    ('dvd', 26): False,
#    ('business', 26): False,
#    ('hun', 26): False,
#    ('dying', 26): False,
#    ('glass', 26): False,
#    ('tear', 26): False,
#    ('web', 26): False,
#    ('aint', 26): False,
#    ('promise', 26): False,
#    ('huge', 26): False,
#    ('profile', 25): False,
#    ('self', 25): False,
#    ('graduation', 25): False,
#    ('woo', 25): False,
#    ('happens', 25): False,
#    ('tom', 25): False,
#    ('asking', 25): False,
#    ('although', 25): False,
#    ('son', 25): False,
#    ('lame', 25): False,
#    ('awful', 25): False,
#    ('sum', 25): False,
#    ('wednesday', 25): False,
#    ('track', 25): False,
#    ('event', 25): False,
#    ('bro', 25): False,
#    ('type', 25): False,
#    ('behind', 25): False,
#    ('trouble', 25): False,
#    ('twilight', 25): False,
#    ('idk', 25): False,
#    ('spending', 25): False,
#    ('sims', 25): False,
#    ('pc', 25): False,
#    ('american', 25): False,
#    ('rd', 25): False,
#    ('decided', 25): False,
#    ('studio', 24): False,
#    ('straight', 24): False,
#    ('google', 24): False,
#    ('yo', 24): False,
#    ('vega', 24): False,
#    ('gettin', 24): False,
#    ('nobody', 24): False,
#    ('mile', 24): False,
#    ('vip', 24): False,
#    ('enjoyed', 24): False,
#    ('sadly', 24): False,
#    ('wat', 24): False,
#    ('teacher', 24): False,
#    ('taylor', 24): False,
#    ('sarah', 24): False,
#    ('match', 24): False,
#    ('met', 24): False,
#    ('needed', 24): False,
#    ('mcfly', 24): False,
#    ('coz', 24): False,
#    ('ended', 24): False,
#    ('de', 24): False,
#    ('support', 24): False,
# ...
#    ('shower', 67): False,
#    ('shopping', 67): False,
#    ('run', 66): False,
#    ('award', 66): False,
#    ('started', 66): False,
#    ('rest', 66): False,
#    ('k', 66): False,
#    ('g', 66): False,
#    ('blog', 66): False,
#    ('else', 66): False,
#    ('computer', 65): False,
#    ('quite', 65): False,
#    ('forgot', 65): False,
#    ('dude', 65): False,
#    ('hand', 65): False,
#    ('ah', 65): False,
#    ('tried', 65): False,
#    ('train', 64): False,
#    ('hug', 64): False,
#    ('alone', 64): False,
#    ('btw', 63): False,
#    ('wont', 63): False,
#    ('cat', 63): False,
#    ('enjoying', 63): False,
#    ('reading', 63): False,
#    ('boring', 63): False,
#    ('lucky', 63): False,
#    ('rock', 62): False,
#    ('open', 62): False,
#    ('link', 62): False,
#    ('wake', 62): False,
#    ('la', 62): False,
#    ('page', 61): False,
#    ('photo', 61): False,
#    ('either', 61): False,
#    ('sigh', 61): False,
#    ('yea', 61): False,
#    ('boo', 60): False,
#    ('turn', 60): False,
#    ('meet', 60): False,
#    ('raining', 60): False,
#    ('crap', 60): False,
#    ('kind', 59): False,
#    ('course', 59): False,
#    ('heart', 59): False,
#    ('site', 59): False,
#    ('hit', 59): False,
#    ('leaving', 59): False,
#    ('facebook', 59): False,
#    ('breakfast', 59): False,
#    ('send', 58): False,
#    ('fine', 58): False,
#    ('l', 58): False,
#    ('ago', 58): False,
#    ('true', 58): False,
#    ('problem', 58): False,
#    ('june', 57): False,
#    ('seeing', 57): False,
#    ('hungry', 57): False,
#    ('mr', 57): False,
#    ('afternoon', 57): False,
#    ('super', 57): False,
#    ('cuz', 57): False,
#    ('mum', 56): False,
#    ('favorite', 56): False,
#    ('listen', 56): False,
#    ('internet', 56): False,
#    ('high', 56): False,
#    ('add', 56): False,
#    ('asleep', 56): False,
#    ('concert', 56): False,
#    ('happened', 56): False,
#    ('air', 56): False,
#    ('evening', 56): False,
#    ('story', 55): False,
#    ('move', 55): False,
#    ('hoping', 55): False,
#    ('drink', 55): False,
#    ('nd', 55): False,
#    ('news', 55): False,
#    ('using', 55): False,
#    ('starting', 55): False,
#    ('loved', 55): False,
#    ('com', 55): False,
#    ('line', 54): False,
#    ('test', 54): False,
#    ('lmao', 54): False,
#    ('homework', 54): False,
#    ('sister', 54): False,
#    ('city', 54): False,
#    ('seems', 54): False,
#    ('died', 53): False,
#    ('smile', 53): False,
#    ('awake', 53): False,
#    ('broke', 53): False,
#    ('ticket', 53): False,
#    ('second', 53): False,
#    ('care', 53): False,
#    ('town', 52): False,
#    ('h', 52): False,
#    ('change', 52): False,
#    ('sleeping', 52): False,
#    ('study', 52): False,
#    ('tommcfly', 51): False,
#    ('mind', 51): False,
#    ('told', 51): False,
#    ('til', 51): False,
#    ('park', 51): False,
#    ('ride', 51): False,
#    ('email', 51): False,
#    ('seriously', 50): False,
#    ('v', 50): False,
#    ('catch', 50): False,
#    ('xd', 50): False,
#    ('heading', 50): False,
#    ('studying', 50): False,
#    ('gym', 50): False,
#    ('dear', 50): False,
#    ('set', 50): False,
#    ('meeting', 50): False,
#    ('write', 50): False,
#    ('jonas', 50): False,
#    ('agree', 50): False,
#    ('pain', 50): False,
#    ('sore', 49): False,
#    ('close', 49): False,
#    ('voice', 49): False,
#    ('red', 49): False,
#    ('sometimes', 49): False,
#    ('walk', 49): False,
#    ('couple', 49): False,
#    ('black', 49): False,
#    ('online', 49): False,
#    ('sunny', 48): False,
#    ('pay', 48): False,
#    ('pool', 48): False,
#    ('store', 48): False,
#    ('dead', 48): False,
#    ('ice', 47): False,
#    ('talking', 47): False,
#    ('laptop', 47): False,
#    ('happen', 47): False,
#    ('drive', 47): False,
#    ('bring', 47): False,
#    ('min', 47): False,
#    ('hang', 47): False,
#    ('bought', 47): False,
#    ('account', 47): False,
#    ('ive', 47): False,
#    ('jealous', 47): False,
#    ('lady', 47): False,
#    ('foot', 47): False,
#    ('ipod', 46): False,
#    ('answer', 46): False,
#    ('vote', 46): False,
#    ('list', 46): False,
#    ('lil', 46): False,
#    ('wishing', 46): False,
#    ('flight', 46): False,
#    ('slow', 46): False,
#    ('bus', 46): False,
#    ('tweeting', 45): False,
#    ('wonderful', 45): False,
#    ('fail', 45): False,
#    ('chocolate', 45): False,
#    ('tea', 45): False,
#    ('bday', 45): False,
#    ('cleaning', 45): False,
#    ('fall', 45): False,
#    ('ate', 45): False,
#    ('number', 45): False,
#    ('worth', 45): False,
#    ('aw', 44): False,
#    ('ask', 44): False,
#    ('together', 44): False,
#    ('called', 44): False,
#    ('church', 44): False,
#    ('inside', 44): False,
#    ('cut', 44): False,
#    ('date', 44): False,
#    ('youtube', 44): False,
#    ('fb', 44): False,
#    ('goin', 44): False,
#    ('forget', 44): False,
#    ('note', 43): False,
#    ('visit', 43): False,
#    ('three', 43): False,
#    ('window', 43): False,
#    ('math', 43): False,
#    ('tour', 43): False,
#    ('cheer', 43): False,
#    ('anyway', 43): False,
#    ('short', 43): False,
#    ('scared', 43): False,
#    ('holiday', 43): False,
#    ('cream', 42): False,
#    ('reason', 42): False,
#    ('apparently', 42): False,
#    ('finish', 42): False,
#    ('bout', 42): False,
#    ('soooo', 42): False,
#    ('episode', 42): False,
#    ('awww', 42): False,
#    ('weird', 42): False,
#    ('age', 42): False,
#    ('ahhh', 42): False,
#    ('ddlovato', 42): False,
#    ('learn', 41): False,
#    ('album', 41): False,
#    ('writing', 41): False,
#    ('le', 41): False,
#    ('bye', 41): False,
#    ('seem', 41): False,
#    ('shame', 41): False,
#    ('clean', 41): False,
#    ('side', 41): False,
#    ('shoe', 41): False,
#    ('mac', 40): False,
#    ('rather', 40): False,
#    ('worry', 40): False,
#    ('july', 40): False,
#    ('point', 40): False,
#    ('ppl', 40): False,
#    ('chance', 40): False,
#    ('nap', 40): False,
#    ('mad', 40): False,
#    ('team', 40): False,
#    ('congrats', 40): False,
#    ('sunshine', 40): False,
#    ('person', 40): False,
#    ('sent', 39): False,
#    ('top', 39): False,
#    ('wear', 39): False,
#    ('radio', 39): False,
#    ('definitely', 39): False,
#    ('flu', 39): False,
#    ('instead', 39): False,
#    ('fast', 39): False,
#    ('tuesday', 39): False,
#    ('blue', 38): False,
#    ('f', 38): False,
#    ('star', 38): False,
#    ('london', 38): False,
#    ('english', 38): False,
#    ('shot', 38): False,
#    ('understand', 38): False,
#    ('water', 38): False,
#    ('xxx', 38): False,
#    ('j', 38): False,
#    ('dance', 38): False,
#    ('paper', 37): False,
#    ('si', 37): False,
#    ('band', 37): False,
#    ('slept', 37): False,
#    ('moving', 37): False,
#    ('david', 37): False,
#    ('interesting', 37): False,
#    ('wonder', 37): False,
#    ('easy', 37): False,
#    ('camp', 37): False,
#    ('sleepy', 37): False,
#    ('clothes', 36): False,
#    ('loving', 36): False,
#    ('hangover', 36): False,
#    ('throat', 36): False,
#    ('power', 36): False,
#    ('pick', 36): False,
#    ('nick', 36): False,
#    ('knew', 36): False,
#    ('worst', 36): False,
#    ('service', 36): False,
#    ('ahh', 36): False,
#    ('beer', 36): False,
#    ('unfortunately', 36): False,
#    ('yummy', 36): False,
#    ('broken', 36): False,
#    ('yep', 36): False,
#    ('running', 36): False,
#    ('doesnt', 36): False,
#    ('parent', 36): False,
#    ('moon', 35): False,
#    ('woman', 35): False,
#    ('fell', 35): False,
#    ('supposed', 35): False,
#    ('followfriday', 35): False,
#    ('miley', 35): False,
#    ('join', 35): False,
#    ('fix', 35): False,
#    ('bitch', 35): False,
#    ('hubby', 35): False,
#    ('perfect', 35): False,
#    ('wtf', 35): False,
#    ('nope', 34): False,
#    ('angel', 34): False,
#    ('thx', 34): False,
#    ('xoxo', 34): False,
#    ('random', 34): False,
#    ('pas', 34): False,
#    ('project', 34): False,
#    ('horrible', 34): False,
#    ('boyfriend', 34): False,
#    ('dm', 34): False,
#    ('hr', 34): False,
#    ('bet', 34): False,
#    ('em', 34): False,
#    ('hmmm', 33): False,
#    ('doctor', 33): False,
#    ('mtv', 33): False,
#    ('special', 33): False,
#    ('da', 33): False,
#    ('shirt', 33): False,
#    ('felt', 33): False,
#    ('wine', 33): False,
#    ('mood', 33): False,
#    ('storm', 33): False,
#    ('question', 33): False,
#    ('ring', 33): False,
#    ('lonely', 33): False,
#    ('spend', 33): False,
#    ('yr', 33): False,
#    ('whatever', 33): False,
#    ('hmm', 32): False,
#    ('cake', 32): False,
#    ('havent', 32): False,
#    ('watchin', 32): False,
#    ('driving', 32): False,
#    ('gave', 32): False,
#    ('plus', 32): False,
#    ('via', 32): False,
#    ('country', 32): False,
#    ('wedding', 32): False,
#    ('forever', 32): False,
#    ('order', 32): False,
#    ('chat', 32): False,
#    ('light', 32): False,
#    ('bike', 32): False,
#    ('everybody', 32): False,
#    ('joe', 31): False,
#    ('message', 31): False,
#    ('drinking', 31): False,
#    ('load', 31): False,
#    ('along', 31): False,
#    ('fml', 31): False,
#    ('vacation', 31): False,
#    ('fair', 31): False,
#    ('apple', 31): False,
#    ('camera', 31): False,
#    ('ouch', 31): False,
#    ('sat', 31): False,
#    ('garden', 31): False,
#    ('bbq', 31): False,
#    ('past', 31): False,
#    ('babe', 31): False,
#    ('lakers', 31): False,
#    ('green', 31): False,
#    ('result', 31): False,
#    ('revision', 30): False,
#    ('asked', 30): False,
#    ('mail', 30): False,
#    ('gorgeous', 30): False,
#    ('wondering', 30): False,
#    ('jus', 30): False,
#    ('worried', 30): False,
#    ('puppy', 30): False,
#    ('honey', 30): False,
#    ('exactly', 30): False,
#    ('bloody', 30): False,
#    ('single', 30): False,
#    ('leg', 30): False,
#    ('moment', 30): False,
#    ('shoot', 30): False,
#    ('thursday', 30): False,
#    ('wit', 30): False,
#    ('disappointed', 30): False,
#    ('saying', 30): False,
#    ('fly', 30): False,
#    ('dress', 30): False,
#    ('demi', 30): False,
#    ('bag', 30): False,
#    ('alright', 30): False,
#    ('blah', 30): False,
#    ('goodbye', 30): False,
#    ('spent', 29): False,
#    ('played', 29): False,
#    ('front', 29): False,
#    ('fact', 29): False,
#    ('walking', 29): False,
#    ('sale', 29): False,
#    ('matter', 29): False,
#    ('cover', 29): False,
#    ('beat', 29): False,
#    ('app', 29): False,
#    ('body', 29): False,
#    ('ooh', 29): False,
#    ('box', 29): False,
#    ('guitar', 29): False,
#    ('absolutely', 29): False,
#    ('mommy', 29): False,
#    ('hanging', 29): False,
#    ('relaxing', 29): False,
#    ('passed', 29): False,
#    ('tummy', 29): False,
#    ('uk', 29): False,
#    ('eh', 29): False,
#    ('due', 29): False,
#    ('upset', 29): False,
#    ('kill', 29): False,
#    ('living', 29): False,
#    ('french', 29): False,
#    ('killing', 29): False,
#    ('record', 29): False,
#    ('longer', 29): False,
#    ('whats', 29): False,
#    ('near', 29): False,
#    ('traffic', 29): False,
#    ('co', 29): False,
#    ('touch', 28): False,
#    ('figure', 28): False,
#    ('arm', 28): False,
#    ('turned', 28): False,
#    ('group', 28): False,
#    ('share', 28): False,
#    ('different', 28): False,
#    ('posted', 28): False,
#    ('hill', 28): False,
#    ('fit', 28): False,
#    ('sign', 28): False,
#    ('warm', 28): False,
#    ('wet', 28): False,
#    ('bummed', 28): False,
#    ('worked', 28): False,
#    ('safe', 28): False,
#    ('website', 28): False,
#    ('comment', 28): False,
#    ('lazy', 28): False,
#    ('smell', 28): False,
#    ('fucking', 28): False,
#    ('trailer', 28): False,
#    ('card', 28): False,
#    ('hospital', 28): False,
#    ('xo', 28): False,
#    ('john', 28): False,
#    ('ohh', 28): False,
#    ('stand', 27): False,
#    ('case', 27): False,
#    ('jonasbrothers', 27): False,
#    ('father', 27): False,
#    ('singing', 27): False,
#    ('freaking', 27): False,
#    ('art', 27): False,
#    ('cup', 27): False,
#    ('club', 27): False,
#    ('pizza', 27): False,
#    ('rainy', 27): False,
#    ('version', 27): False,
#    ('packing', 27): False,
#    ('ache', 27): False,
#    ('die', 27): False,
#    ('airport', 27): False,
#    ('magic', 27): False,
#    ('yup', 27): False,
#    ('deal', 27): False,
#    ('officially', 27): False,
#    ('white', 27): False,
#    ('looked', 27): False,
#    ('drunk', 27): False,
#    ('door', 27): False,
#    ('rip', 27): False,
#    ('earlier', 27): False,
#    ('shop', 26): False,
#    ('ball', 26): False,
#    ('hold', 26): False,
#    ('chris', 26): False,
#    ('ear', 26): False,
#    ('dark', 26): False,
#    ('except', 26): False,
#    ('company', 26): False,
#    ('silly', 26): False,
#    ('stomach', 26): False,
#    ('round', 26): False,
#    ('failed', 26): False,
#    ('proud', 26): False,
#    ('joy', 26): False,
#    ('chicken', 26): False,
#    ('dvd', 26): False,
#    ('business', 26): False,
#    ('hun', 26): False,
#    ('dying', 26): False,
#    ('glass', 26): False,
#    ('tear', 26): False,
#    ('web', 26): False,
#    ('aint', 26): False,
#    ('promise', 26): False,
#    ('huge', 26): False,
#    ('profile', 25): False,
#    ('self', 25): False,
#    ('graduation', 25): False,
#    ('woo', 25): False,
#    ('happens', 25): False,
#    ('tom', 25): False,
#    ('asking', 25): False,
#    ('although', 25): False,
#    ('son', 25): False,
#    ('lame', 25): False,
#    ('awful', 25): False,
#    ('sum', 25): False,
#    ('wednesday', 25): False,
#    ('track', 25): False,
#    ('event', 25): False,
#    ('bro', 25): False,
#    ('type', 25): False,
#    ('behind', 25): False,
#    ('trouble', 25): False,
#    ('twilight', 25): False,
#    ('idk', 25): False,
#    ('spending', 25): False,
#    ('sims', 25): False,
#    ('pc', 25): False,
#    ('american', 25): False,
#    ('rd', 25): False,
#    ('decided', 25): False,
#    ('studio', 24): False,
#    ('straight', 24): False,
#    ('google', 24): False,
#    ('yo', 24): False,
#    ('vega', 24): False,
#    ('gettin', 24): False,
#    ('nobody', 24): False,
#    ('mile', 24): False,
#    ('vip', 24): False,
#    ('enjoyed', 24): False,
#    ('sadly', 24): False,
#    ('wat', 24): False,
#    ('teacher', 24): False,
#    ('taylor', 24): False,
#    ('sarah', 24): False,
#    ('match', 24): False,
#    ('met', 24): False,
#    ('needed', 24): False,
#    ('mcfly', 24): False,
#    ('coz', 24): False,
#    ('ended', 24): False,
#    ('de', 24): False,
#    ('support', 24): False,
#    ('id', 24): False,
#    ('myspace', 24): False,
#    ('cook', 24): False,
#    ('cd', 24): False,
#    ('usually', 24): False,
#    ('screen', 24): False,
#    ('alex', 24): False,
#    ('film', 24): False,
#    ('interview', 24): False,
#    ('france', 24): False,
#    ('currently', 24): False,
#    ('normal', 24): False,
#    ('laugh', 24): False,
#    ('cheese', 24): False,
#    ('sexy', 23): False,
#    ('nose', 23): False,
#    ('report', 23): False,
#    ('worse', 23): False,
#    ('major', 23): False,
#    ('south', 23): False,
#    ('tan', 23): False,
#    ('sort', 23): False,
#    ('meant', 23): False,
#    ('wife', 23): False,
#    ('couch', 23): False,
#    ('luv', 23): False,
#    ('gig', 23): False,
#    ('mmm', 23): False,
#    ('delicious', 23): False,
#    ('ton', 23): False,
#    ('sold', 23): False,
#    ('ahead', 23): False,
#    ('tree', 23): False,
#    ('count', 23): False,
#    ('low', 23): False,
#    ('upload', 23): False,
#    ('plane', 23): False,
#    ('college', 23): False,
#    ('bb', 23): False,
#    ('annoying', 23): False,
#    ('positive', 23): False,
#    ('especially', 23): False,
#    ('finger', 22): False,
#    ('talent', 22): False,
#    ('crash', 22): False,
#    ('def', 22): False,
#    ('ny', 22): False,
#    ('return', 22): False,
#    ('tip', 22): False,
#    ('arrived', 22): False,
#    ('hahah', 22): False,
#    ('nyc', 22): False,
#    ('ran', 22): False,
#    ('isnt', 22): False,
#    ('daughter', 22): False,
#    ('scary', 22): False,
#    ('healthy', 22): False,
#    ('depressed', 22): False,
#    ('teeth', 22): False,
#    ('knee', 22): False,
#    ('chillin', 22): False,
#    ('street', 22): False,
#    ('hotel', 22): False,
#    ('completely', 22): False,
#    ('indeed', 22): False,
#    ('cousin', 22): False,
#    ('waking', 22): False,
#    ('exciting', 22): False,
#    ('mi', 22): False,
#    ('alot', 22): False,
#    ('pink', 22): False,
#    ('changed', 22): False,
#    ('degree', 22): False,
#    ('finding', 22): False,
#    ('soccer', 22): False,
#    ('finishing', 22): False,
#    ('yall', 22): False,
#    ('bank', 22): False,
#    ('kiss', 22): False,
#    ('click', 22): False,
#    ('shut', 22): False,
#    ('liked', 22): False,
#    ('butt', 22): False,
#    ('state', 22): False,
#    ('terrible', 22): False,
#    ('fat', 21): False,
#    ('killed', 21): False,
#    ('ff', 21): False,
#    ('drop', 21): False,
#    ('shift', 21): False,
#    ('download', 21): False,
#    ('festival', 21): False,
#    ('contact', 21): False,
#    ...},
#   0)]

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %%
train_set, test_set = feature_set[:10000], feature_set[10000:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
print(nltk.classify.accuracy(classifier, test_set))
classifier.show_most_informative_features(5)
# Out:
# 0.5026
# Most Informative Features
#                ('aa', 3) = False               0 : 4      =      1.0 : 1.0
#            ('aaaaah', 4) = False               0 : 4      =      1.0 : 1.0
#              ('aaah', 6) = False               0 : 4      =      1.0 : 1.0
#              ('aah', 10) = False               0 : 4      =      1.0 : 1.0
#             ('aaron', 7) = False               0 : 4      =      1.0 : 1.0
